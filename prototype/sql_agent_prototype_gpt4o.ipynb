# %% [markdown]
# ## Check DB Connection

# %%
import os
from sqlalchemy import create_engine
from dotenv import load_dotenv
from langchain_community.utilities import SQLDatabase

# %%
from langchain_core.prompts import (
    ChatPromptTemplate,
    FewShotPromptTemplate,
    MessagesPlaceholder,
    PromptTemplate,
    SystemMessagePromptTemplate,
)

# %%
load_dotenv()
# Out:
# True

# %%
# Get the database credentials from environment variables
db_username = os.getenv('DB_USERNAME')
db_password = os.getenv('DB_PASSWORD')
db_host = os.getenv('DB_HOST')
db_port = os.getenv('DB_PORT')
db_name = os.getenv('DB_NAME')

# %%
db_url = f'postgresql://{db_username}:{db_password}@{db_host}:{db_port}/{db_name}'

db = SQLDatabase.from_uri(db_url)

# %% [markdown]
# ## Create SQL Agent

# %%
from langchain_community.agent_toolkits import create_sql_agent 
from langchain_openai import ChatOpenAI

# %%
openai_api_key = os.getenv("OPENAI_API_KEY")
print(openai_api_key)
# Out:
# sk-proj-WbPv2R7YTidWgBSMvIjST3BlbkFJyjpl0kw0Ww7W96WFNx78

# %%
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0, api_key=openai_api_key)

# %% [markdown]
# ## Prompt Template engineering

# %%
context = db.get_context()
print(context["table_info"])
# Out:
# CREATE TABLE company (
# 	company_logo_url TEXT,
# 	company_logo_text TEXT,
# 	company_name TEXT,
# 	relation_to_event TEXT,
# 	event_url TEXT,
# 	company_revenue BIGINT,
# 	n_employees BIGINT,
# 	company_phone TEXT,
# 	company_founding_year BIGINT,
# 	company_address TEXT,
# 	company_industry TEXT,
# 	company_overview TEXT,
# 	homepage_url TEXT,
# 	linkedin_company_url TEXT,
# 	homepage_base_url TEXT,
# 	company_logo_url_on_event_page TEXT,
# 	company_logo_match_flag TEXT,
# 	company_country TEXT
# )
#
# /*
# 3 rows from company table:
# company_logo_url	company_logo_text	company_name	relation_to_event	event_url	company_revenue	n_employees	company_phone	company_founding_year	company_address	company_industry	company_overview	homepage_url	linkedin_company_url	homepage_base_url	company_logo_url_on_event_page	company_logo_match_flag	company_country
# https://d1hbpr09pwz0sk.cloudfront.net/logo_url/100-women-in-finance-6a062f47	Women in Finance	100 Women In Finance	partner	https://apac.commoditytradingweek.com/	0	11	Unknown	2001	None	Financial Services	100 Women in Finance strengthens the global finance industry by empowering women to achieve their pr	https://100women.org/events/	https://www.linkedin.com/company/100-women-in-finance/about	Unknown	https://apac.commoditytradingweek.com/wp-content/uploads/2022/03/100wif_web-1.png	yes	Unknown
# https://media.licdn.com/dms/image/C4D0BAQHlTYAmrCwYOw/company-logo_200_200/0/1671349864369/bbgc_serv	BBGC	Bbgc	sponsor	https://apac.commoditytradingweek.com/	0	51	Unknown	0	None	It Services And It Consulting	Business Benefits Global Consulting (BBGC) is a multinational consultancy firm with offices in Middl	Unknown	https://it.linkedin.com/company/bbgcservices/about	Unknown	https://apac.commoditytradingweek.com/wp-content/uploads/2022/03/BBGC_WEB_logo-1.png	yes	Unknown
# https://d1hbpr09pwz0sk.cloudfront.net/logo_url/hr-maritime-c13714f3	HR MARITIME	Hr Maritime	partner	https://apac.commoditytradingweek.com/	2	2	+41 22 732 57 00	2008	1-3 Rue De Chantepoulet, Geneva, Geneva 1201, CH	Maritime Transportation	HR Maritime is a Geneva based company providing services to the International Trading and Shipping i	http://www.hr-maritime.com	https://ch.linkedin.com/company/hr-maritime/about	Unknown	https://apac.commoditytradingweek.com/wp-content/uploads/2022/03/HR_logo-2.png	yes	CH
# */
#
#
# CREATE TABLE event (
# 	event_logo_url TEXT,
# 	event_name TEXT,
# 	event_start_date TEXT,
# 	event_end_date TEXT,
# 	event_venue TEXT,
# 	event_country TEXT,
# 	event_description TEXT,
# 	event_url TEXT,
# 	event_industry TEXT
# )
#
# /*
# 3 rows from event table:
# event_logo_url	event_name	event_start_date	event_end_date	event_venue	event_country	event_description	event_url	event_industry
# http://expo.overseaseducation.sg/v.fastcdn.co/u/0e18fcd3/57786581-0-Untitled-.png	World University Expo @ SUNTEC	2024-07-06	2024-07-06	SUNTEC Convention Centre	None	Join our World University Expo this Saturday, 6 July 2024 12-6.30pm at SUNTEC whereby you can meet s	http://expo.overseaseducation.sg/	Education
# https://ahiceconference.com/southeastasia/wp-content/uploads/sites/2/2024/05/AHICE-SEA-Logo.jpg	AHICE South East Asia	2025-02-25	2025-02-26	Pan Pacific Singapore	None	The Asian Hotel Industry Conference & Exhibition (AHICE) hosted by HM Magazine made its South East A	https://ahiceconference.com/southeastasia/	Education
# https://apac.commoditytradingweek.com/wp-content/uploads/2024/02/cropped-ctw-apac-main-2.png	Commodity Trading Week APAC	2025-02-25	2025-02-26	Marina Bay Sands	None	Commodity Trading Week APAC is the premier event in the Asia Pacific region for the commodity indust	https://apac.commoditytradingweek.com/	Finance
# */
#
#
# CREATE TABLE people (
# 	index BIGINT,
# 	first_name TEXT,
# 	middle_name TEXT,
# 	last_name TEXT,
# 	job_title TEXT,
# 	person_city TEXT,
# 	person_state TEXT,
# 	person_country TEXT,
# 	email_pattern TEXT,
# 	homepage_base_url TEXT,
# 	duration_in_current_job TEXT,
# 	duration_in_current_company TEXT,
# 	email_address TEXT,
# 	email_valid BOOLEAN,
# 	full_name TEXT,
# 	years_in_current_job BIGINT
# )
#
# /*
# 3 rows from people table:
# index	first_name	middle_name	last_name	job_title	person_city	person_state	person_country	email_pattern	homepage_base_url	duration_in_current_job	duration_in_current_company	email_address	email_valid	full_name	years_in_current_job
# 0	Cynthia	None	Battini	Indirect Buyer	None	None	France	None	ariane.group	None	None	None	False	Cynthia Battini	0
# 1	Alexander	None	McClure	Public Relations	Austin	TX	US	None	amazon.com	None	None	None	False	Alexander Mcclure	0
# 2	Nadir	None	Shaari	SEO Junior Account Manager	London	None	GB	[first].[last]	artefact.com	None	None	nadir.shaari@artefact.com	True	Nadir Shaari	0
# */

# %%
import ast
import re


def query_as_list(db, query):
    res = db.run(query)
    res = [el for sub in ast.literal_eval(res) for el in sub if el]
    res = [re.sub(r"\b\d+\b", "", string).strip() for string in res]
    return list(set(res))

# %%
system = """You are an agent designed to interact with a SQL database.
Given an input question, create a syntactically correct {dialect} query to run, then look at the results of the query and return the answer.
Try more advacned queries if the normal query does not result in any responses.
You can order the results by a relevant column to return the most interesting examples in the database.
Never query for all the columns from a specific table, only ask for the relevant columns given the question.
You have access to tools for interacting with the database.
Only use the given tools. Only use the information returned by the tools to construct your final answer.
You MUST double check your query before executing it. If you get an error while executing a query, rewrite the query and try again.

DO NOT make any DML statements (INSERT, UPDATE, DELETE, DROP etc.) to the database.

If you need to filter on a proper noun, you must ALWAYS first look up the filter value using the "search_proper_nouns" tool! 

You have access to the following tables: {table_names}

If the question does not seem related to the database, explain to the user why you can't find the answer.

Return the response in a nice format and visualize it if possible.

Use the following information about the tables to retrieve accurate answers.



CREATE TABLE company (
	company_logo_url TEXT, 
	company_logo_text TEXT, 
	company_name TEXT, 
	relation_to_event TEXT, 
	event_url TEXT, 
	company_revenue BIGINT, 
	n_employees BIGINT, 
	company_phone TEXT, 
	company_founding_year BIGINT, 
	company_address TEXT, 
	company_industry TEXT, 
	company_overview TEXT, 
	homepage_url TEXT, 
	linkedin_company_url TEXT, 
	homepage_base_url TEXT, 
	company_logo_url_on_event_page TEXT, 
	company_logo_match_flag TEXT, 
	company_country TEXT
)

/*
3 rows from company table:
company_logo_url	company_logo_text	company_name	relation_to_event	event_url	company_revenue	n_employees	company_phone	company_founding_year	company_address	company_industry	company_overview	homepage_url	linkedin_company_url	homepage_base_url	company_logo_url_on_event_page	company_logo_match_flag	company_country
https://d1hbpr09pwz0sk.cloudfront.net/logo_url/100-women-in-finance-6a062f47	Women in Finance	100 Women In Finance	partner	https://apac.commoditytradingweek.com/	0	11	Unknown	2001	None	Financial Services	100 Women in Finance strengthens the global finance industry by empowering women to achieve their pr	https://100women.org/events/	https://www.linkedin.com/company/100-women-in-finance/about	Unknown	https://apac.commoditytradingweek.com/wp-content/uploads/2022/03/100wif_web-1.png	yes	Unknown
https://media.licdn.com/dms/image/C4D0BAQHlTYAmrCwYOw/company-logo_200_200/0/1671349864369/bbgc_serv	BBGC	Bbgc	sponsor	https://apac.commoditytradingweek.com/	0	51	Unknown	0	None	It Services And It Consulting	Business Benefits Global Consulting (BBGC) is a multinational consultancy firm with offices in Middl	Unknown	https://it.linkedin.com/company/bbgcservices/about	Unknown	https://apac.commoditytradingweek.com/wp-content/uploads/2022/03/BBGC_WEB_logo-1.png	yes	Unknown
https://d1hbpr09pwz0sk.cloudfront.net/logo_url/hr-maritime-c13714f3	HR MARITIME	Hr Maritime	partner	https://apac.commoditytradingweek.com/	2	2	+41 22 732 57 00	2008	1-3 Rue De Chantepoulet, Geneva, Geneva 1201, CH	Maritime Transportation	HR Maritime is a Geneva based company providing services to the International Trading and Shipping i	http://www.hr-maritime.com	https://ch.linkedin.com/company/hr-maritime/about	Unknown	https://apac.commoditytradingweek.com/wp-content/uploads/2022/03/HR_logo-2.png	yes	CH
*/


CREATE TABLE event (
	event_logo_url TEXT, 
	event_name TEXT, 
	event_start_date TEXT, 
	event_end_date TEXT, 
	event_venue TEXT, 
	event_country TEXT, 
	event_description TEXT, 
	event_url TEXT, 
	event_industry TEXT
)

/*
3 rows from event table:
event_logo_url	event_name	event_start_date	event_end_date	event_venue	event_country	event_description	event_url	event_industry
http://expo.overseaseducation.sg/v.fastcdn.co/u/0e18fcd3/57786581-0-Untitled-.png	World University Expo @ SUNTEC	2024-07-06	2024-07-06	SUNTEC Convention Centre	None	Join our World University Expo this Saturday, 6 July 2024 12-6.30pm at SUNTEC whereby you can meet s	http://expo.overseaseducation.sg/	Education
https://ahiceconference.com/southeastasia/wp-content/uploads/sites/2/2024/05/AHICE-SEA-Logo.jpg	AHICE South East Asia	2025-02-25	2025-02-26	Pan Pacific Singapore	None	The Asian Hotel Industry Conference & Exhibition (AHICE) hosted by HM Magazine made its South East A	https://ahiceconference.com/southeastasia/	Education
https://apac.commoditytradingweek.com/wp-content/uploads/2024/02/cropped-ctw-apac-main-2.png	Commodity Trading Week APAC	2025-02-25	2025-02-26	Marina Bay Sands	None	Commodity Trading Week APAC is the premier event in the Asia Pacific region for the commodity indust	https://apac.commoditytradingweek.com/	Finance
*/


CREATE TABLE people (
	index BIGINT, 
	first_name TEXT, 
	middle_name TEXT, 
	last_name TEXT, 
	job_title TEXT, 
	person_city TEXT, 
	person_state TEXT, 
	person_country TEXT, 
	email_pattern TEXT, 
	homepage_base_url TEXT, 
	duration_in_current_job TEXT, 
	duration_in_current_company TEXT, 
	email_address TEXT, 
	email_valid BOOLEAN, 
	full_name TEXT, 
	years_in_current_job BIGINT
)

/*
3 rows from people table:
index	first_name	middle_name	last_name	job_title	person_city	person_state	person_country	email_pattern	homepage_base_url	duration_in_current_job	duration_in_current_company	email_address	email_valid	full_name	years_in_current_job
0	Cynthia	None	Battini	Indirect Buyer	None	None	France	None	ariane.group	None	None	None	False	Cynthia Battini	0
1	Alexander	None	McClure	Public Relations	Austin	TX	US	None	amazon.com	None	None	None	False	Alexander Mcclure	0
2	Nadir	None	Shaari	SEO Junior Account Manager	London	None	GB	[first].[last]	artefact.com	None	None	nadir.shaari@artefact.com	True	Nadir Shaari	0
*/

event and company tables can be merged using ‘event_url’ column.
company and people data can be merged using ‘homepage_base_url’ column.
Each event_url corresponds to a unique event, and each homepage_base_url can
be interpreted as a unique company.
 """

prompt = ChatPromptTemplate.from_messages(
    [("system", system), ("human", "{input}"), MessagesPlaceholder("agent_scratchpad")]
)
agent = create_sql_agent(
    llm=llm,
    db=db,
    prompt=prompt,
    agent_type="tool-calling",
    verbose=True,
)

# %%
import pprint

chunks = []

async for chunk in agent.astream(
    {"input": "Find all sales people working in Singapore"}
):
    chunks.append(chunk)
    print("------")
    pprint.pprint(chunk, depth=5)
# Out:
# > Entering new SQL Agent Executor chain...
# ------
# [AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_mQkMHUsNs0comaEBrN4JEBoz', 'function': {'arguments': '{"query":"SELECT first_name, last_name, job_title, company_name, person_city, person_country FROM people_company WHERE job_title ILIKE \'%sales%\' AND person_country = \'Singapore\'"}', 'name': 'sql_db_query_checker'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_0f03d4f0ee'}, id='run-ef866a58-9903-4ece-b03f-c1d948a00213', tool_calls=[{'name': 'sql_db_query_checker', 'args': {'query': "SELECT first_name, last_name, job_title, company_name, person_city, person_country FROM people_company WHERE job_title ILIKE '%sales%' AND person_country = 'Singapore'"}, 'id': 'call_mQkMHUsNs0comaEBrN4JEBoz', 'type': 'tool_call'}], tool_call_chunks=[{'name': 'sql_db_query_checker', 'args': '{"query":"SELECT first_name, last_name, job_title, company_name, person_city, person_country FROM people_company WHERE job_title ILIKE \'%sales%\' AND person_country = \'Singapore\'"}', 'id': 'call_mQkMHUsNs0comaEBrN4JEBoz', 'index': 0, 'type': 'tool_call_chunk'}])]
#
# Invoking: `sql_db_query_checker` with `{'query': "SELECT first_name, last_name, job_title, company_name, person_city, person_country FROM people_company WHERE job_title ILIKE '%sales%' AND person_country = 'Singapore'"}`
#
#
# ```sql
# SELECT first_name, last_name, job_title, company_name, person_city, person_country
# FROM people_company
# WHERE job_title ILIKE '%sales%' AND person_country = 'Singapore';
# ```------
# [FunctionMessage(content="```sql\nSELECT first_name, last_name, job_title, company_name, person_city, person_country \nFROM people_company \nWHERE job_title ILIKE '%sales%' AND person_country = 'Singapore';\n```", name='sql_db_query_checker')]
# ------
# [AIMessageChunk(content='', additional_kwargs={'tool_calls': [{'index': 0, 'id': 'call_YY9N5I9ysPKXCQzdp9xxwcMt', 'function': {'arguments': '{"query":"SELECT first_name, last_name, job_title, company_name, person_city, person_country FROM people_company WHERE job_title ILIKE \'%sales%\' AND person_country = \'Singapore\'"}', 'name': 'sql_db_query'}, 'type': 'function'}]}, response_metadata={'finish_reason': 'tool_calls', 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_611b667b19'}, id='run-18d58248-7773-439b-aead-f51b947c62d1', tool_calls=[{'name': 'sql_db_query', 'args': {'query': "SELECT first_name, last_name, job_title, company_name, person_city, person_country FROM people_company WHERE job_title ILIKE '%sales%' AND person_country = 'Singapore'"}, 'id': 'call_YY9N5I9ysPKXCQzdp9xxwcMt', 'type': 'tool_call'}], tool_call_chunks=[{'name': 'sql_db_query', 'args': '{"query":"SELECT first_name, last_name, job_title, company_name, person_city, person_country FROM people_company WHERE job_title ILIKE \'%sales%\' AND person_country = \'Singapore\'"}', 'id': 'call_YY9N5I9ysPKXCQzdp9xxwcMt', 'index': 0, 'type': 'tool_call_chunk'}])]
#
# Invoking: `sql_db_query` with `{'query': "SELECT first_name, last_name, job_title, company_name, person_city, person_country FROM people_company WHERE job_title ILIKE '%sales%' AND person_country = 'Singapore'"}`
#
#
# [('Koh', 'Jing How', 'Enterprise Sales SEA PayPal', 'PayPal', None, 'Singapore'), ('Eric', 'Chan', 'Sales Manager', 'ST Engineering North America', 'Singapore', 'Singapore'), ('Poh', '\\-', 'Land Transfer and Land Sales @ Singapore Land Authority (SLA)', 'Singapore Land Authority (SLA)', 'Singapore', 'Singapore'), ('Cao', 'Li', 'Sales', 'Far East Organization', 'Singapore', 'Singapore'), ('Melissa', 'Wong', 'Sales Administrative Executive', 'Far East Organization', 'Singapore', 'Singapore'), ('Mitchell', 'Chan', 'Sales Engineer Splunk', 'Splunk', None, 'Singapore'), ('David', 'Bochsler', 'Vice President of Sales (Asia Pacific & Japan) KnowBe4', 'KnowBe4', None, 'Singapore'), ('Patricia', 'A.', 'Sales Manager ASEAN Siemens', 'Siemens', 'Singapore', 'Singapore'), ('Zhiming', 'Fong', 'Director Strategic Partnerships & Sales, APAC Amadeus', 'Amadeus', None, 'Singapore'), ('Daniel', 'Ang', 'Sales Executive', 'Far East Organization', 'Singapore', 'Singapore'), ('Annabel', 'Chang', 'Sales Development Manager (APJ) KnowBe4', 'KnowBe4', None, 'Singapore'), ('Lawrence', 'Koh', 'Assistant General Manager, Managed Services and Solution Sales', 'StarHub', 'Singapore', 'Singapore'), ('Kimberly', 'Pang', 'Sales Manager', 'StarHub', 'Singapore', 'Singapore'), ('Zheng', 'Teo', 'Sales Manager', 'Far East Hospitality Management (S) Pte Ltd', 'Singapore', 'Singapore'), ('Marie-Frédérique', 'Romain', 'Head of Sales Pacific', 'Airbus Defence and Space', 'Singapore', 'Singapore'), ('Audrey', 'Seow', 'Cluster Director of Sales and Marketing, JW Marriott Singapore and The St Regis Singapore Marriott International', 'Marriott International Hotels, Inc.', None, 'Singapore'), ('Vinny', 'Kim', 'Sales Advisor', 'StarHub', 'Singapore', 'Singapore'), ('Anna', 'Chiang', 'Sales Executive Bloomberg Businessweek', 'Bloomberg', None, 'Singapore'), ('Clarence', 'Lau', 'Assistant Sales Manager', 'Anritsu', 'Singapore', 'Singapore'), ('Vincent', 'Ang', 'Sales Manager Siemens', 'Siemens', None, 'Singapore'), ('Alvin', 'Xu', 'Assistant Director of Sales', 'Far East Hospitality Management (S) Pte Ltd', 'Singapore', 'Singapore'), ('Ericka', 'T.', 'Regional Sales Manager - Indonesia Splunk', 'Splunk', None, 'Singapore'), ('Koon', 'Tay', 'Head, Government Sales', 'StarHub', 'Singapore', 'Singapore'), ('David', 'Lee', 'Assistant Director Of Sales', 'Far East Hospitality Management (S) Pte Ltd', 'Singapore', 'Singapore'), ('Josephine', 'Lim', 'Area Director of Sales and Marketing', 'Far East Hospitality Management (S) Pte Ltd', 'Singapore', 'Singapore'), ('Kershawn', 'Liau', 'Graduate Presales Hewlett Packard Enterprise', 'Hewlett Packard Enterprise', 'Singapore', 'Singapore'), ('Lock', 'Hao', 'Assistant Sales Manager', 'Far East Hospitality Management (S) Pte Ltd', 'Singapore', 'Singapore'), ('Fenny', 'Tan', 'Senior Sales Manager', 'Far East Hospitality Management (S) Pte Ltd', 'Singapore', 'Singapore'), ('Jun', 'Ang', 'Sales Specialist', 'StarHub', 'Singapore', 'Singapore'), ('Joel', 'Lim Xin Yong', 'Salesperson Hewlett Packard Enterprise', 'Hewlett Packard Enterprise', 'Singapore', 'Singapore'), ('Gary', 'T.', 'Commercial Sales Executive Amadeus', 'Amadeus', None, 'Singapore'), ('Greta', 'Yap', 'Regional Sales Manager Darktrace', 'Darktrace', 'Singapore', 'Singapore'), ('Satish', 'Khanna', 'Director Sales Siemens Energy - Power & Gas', 'Siemens', 'Singapore', 'Singapore'), ('Ericka', 'T.', 'Regional Sales Manager - Indonesia Splunk', 'Splunk', None, 'Singapore'), ('Keng', 'Tan', 'Presales Director', 'ST Engineering North America', 'Singapore', 'Singapore'), ('Shabab', 'MK', 'APAC Ecosystem Sales Manager Hewlett Packard Enterprise', 'Hewlett Packard Enterprise', None, 'Singapore'), ('Dave', 'Ong', 'Sales Consultant', 'Far East Organization', 'Singapore', 'Singapore'), ('shikai', 'wang', 'Sales excutive Siemens', 'Siemens', None, 'Singapore'), ('Shruti', 'More', 'Renewals Sales Specialist (ANZ & INDIA) SUSE', 'SUSE', None, 'Singapore'), ('Hpyo', 'Paing', 'Senior Manager Sa ...
# [FunctionMessage(content="[('Koh', 'Jing How', 'Enterprise Sales SEA PayPal', 'PayPal', None, 'Singapore'), ('Eric', 'Chan', 'Sales Manager', 'ST Engineering North America', 'Singapore', 'Singapore'), ('Poh', '\\\\-', 'Land Transfer and Land Sales @ Singapore Land Authority (SLA)', 'Singapore Land Authority (SLA)', 'Singapore', 'Singapore'), ('Cao', 'Li', 'Sales', 'Far East Organization', 'Singapore', 'Singapore'), ('Melissa', 'Wong', 'Sales Administrative Executive', 'Far East Organization', 'Singapore', 'Singapore'), ('Mitchell', 'Chan', 'Sales Engineer Splunk', 'Splunk', None, 'Singapore'), ('David', 'Bochsler', 'Vice President of Sales (Asia Pacific & Japan) KnowBe4', 'KnowBe4', None, 'Singapore'), ('Patricia', 'A.', 'Sales Manager ASEAN Siemens', 'Siemens', 'Singapore', 'Singapore'), ('Zhiming', 'Fong', 'Director Strategic Partnerships & Sales, APAC Amadeus', 'Amadeus', None, 'Singapore'), ('Daniel', 'Ang', 'Sales Executive', 'Far East Organization', 'Singapore', 'Singapore'), ('Annabel', 'Chang', 'Sales Development Manager (APJ) KnowBe4', 'KnowBe4', None, 'Singapore'), ('Lawrence', 'Koh', 'Assistant General Manager, Managed Services and Solution Sales', 'StarHub', 'Singapore', 'Singapore'), ('Kimberly', 'Pang', 'Sales Manager', 'StarHub', 'Singapore', 'Singapore'), ('Zheng', 'Teo', 'Sales Manager', 'Far East Hospitality Management (S) Pte Ltd', 'Singapore', 'Singapore'), ('Marie-Frédérique', 'Romain', 'Head of Sales Pacific', 'Airbus Defence and Space', 'Singapore', 'Singapore'), ('Audrey', 'Seow', 'Cluster Director of Sales and Marketing, JW Marriott Singapore and The St Regis Singapore Marriott International', 'Marriott International Hotels, Inc.', None, 'Singapore'), ('Vinny', 'Kim', 'Sales Advisor', 'StarHub', 'Singapore', 'Singapore'), ('Anna', 'Chiang', 'Sales Executive Bloomberg Businessweek', 'Bloomberg', None, 'Singapore'), ('Clarence', 'Lau', 'Assistant Sales Manager', 'Anritsu', 'Singapore', 'Singapore'), ('Vincent', 'Ang', 'Sales Manager Siemens', 'Siemens', None, 'Singapore'), ('Alvin', 'Xu', 'Assistant Director of Sales', 'Far East Hospitality Management (S) Pte Ltd', 'Singapore', 'Singapore'), ('Ericka', 'T.', 'Regional Sales Manager - Indonesia Splunk', 'Splunk', None, 'Singapore'), ('Koon', 'Tay', 'Head, Government Sales', 'StarHub', 'Singapore', 'Singapore'), ('David', 'Lee', 'Assistant Director Of Sales', 'Far East Hospitality Management (S) Pte Ltd', 'Singapore', 'Singapore'), ('Josephine', 'Lim', 'Area Director of Sales and Marketing', 'Far East Hospitality Management (S) Pte Ltd', 'Singapore', 'Singapore'), ('Kershawn', 'Liau', 'Graduate Presales Hewlett Packard Enterprise', 'Hewlett Packard Enterprise', 'Singapore', 'Singapore'), ('Lock', 'Hao', 'Assistant Sales Manager', 'Far East Hospitality Management (S) Pte Ltd', 'Singapore', 'Singapore'), ('Fenny', 'Tan', 'Senior Sales Manager', 'Far East Hospitality Management (S) Pte Ltd', 'Singapore', 'Singapore'), ('Jun', 'Ang', 'Sales Specialist', 'StarHub', 'Singapore', 'Singapore'), ('Joel', 'Lim Xin Yong', 'Salesperson Hewlett Packard Enterprise', 'Hewlett Packard Enterprise', 'Singapore', 'Singapore'), ('Gary', 'T.', 'Commercial Sales Executive Amadeus', 'Amadeus', None, 'Singapore'), ('Greta', 'Yap', 'Regional Sales Manager Darktrace', 'Darktrace', 'Singapore', 'Singapore'), ('Satish', 'Khanna', 'Director Sales Siemens Energy - Power & Gas', 'Siemens', 'Singapore', 'Singapore'), ('Ericka', 'T.', 'Regional Sales Manager - Indonesia Splunk', 'Splunk', None, 'Singapore'), ('Keng', 'Tan', 'Presales Director', 'ST Engineering North America', 'Singapore', 'Singapore'), ('Shabab', 'MK', 'APAC Ecosystem Sales Manager Hewlett Packard Enterprise', 'Hewlett Packard Enterprise', None, 'Singapore'), ('Dave', 'Ong', 'Sales Consultant', 'Far East Organization', 'Singapore', 'Singapore'), ('shikai', 'wang', 'Sales excutive Siemens', 'Siemens', None, 'Singapore'), ('Shruti', 'More', 'Renewals Sales Specialist (ANZ & INDIA) SUSE', 'SUSE', None, 'Singapore'), ('Hpyo', ...
# Here are the sales people working in Singapore:
#
# 1. **Koh Jing How** - Enterprise Sales SEA at PayPal
# 2. **Eric Chan** - Sales Manager at ST Engineering North America
# 3. **Poh -** Land Transfer and Land Sales at Singapore Land Authority (SLA)
# 4. **Cao Li** - Sales at Far East Organization
# 5. **Melissa Wong** - Sales Administrative Executive at Far East Organization
# 6. **Mitchell Chan** - Sales Engineer at Splunk
# 7. **David Bochsler** - Vice President of Sales (Asia Pacific & Japan) at KnowBe4
# 8. **Patricia A.** - Sales Manager ASEAN at Siemens
# 9. **Zhiming Fong** - Director Strategic Partnerships & Sales, APAC at Amadeus
# 10. **Daniel Ang** - Sales Executive at Far East Organization
# 11. **Annabel Chang** - Sales Development Manager (APJ) at KnowBe4
# 12. **Lawrence Koh** - Assistant General Manager, Managed Services and Solution Sales at StarHub
# 13. **Kimberly Pang** - Sales Manager at StarHub
# 14. **Zheng Teo** - Sales Manager at Far East Hospitality Management (S) Pte Ltd
# 15. **Marie-Frédérique Romain** - Head of Sales Pacific at Airbus Defence and Space
# 16. **Audrey Seow** - Cluster Director of Sales and Marketing at Marriott International Hotels, Inc.
# 17. **Vinny Kim** - Sales Advisor at StarHub
# 18. **Anna Chiang** - Sales Executive at Bloomberg Businessweek
# 19. **Clarence Lau** - Assistant Sales Manager at Anritsu
# 20. **Vincent Ang** - Sales Manager at Siemens
#
# This is just a selection of the sales professionals in Singapore. If you need more names or specific details, let me know!
#
# > Finished chain.
# ------
# [AIMessage(content='Here are the sales people working in Singapore:\n\n1. **Koh Jing How** - Enterprise Sales SEA at PayPal\n2. **Eric Chan** - Sales Manager at ST Engineering North America\n3. **Poh -** Land Transfer and Land Sales at Singapore Land Authority (SLA)\n4. **Cao Li** - Sales at Far East Organization\n5. **Melissa Wong** - Sales Administrative Executive at Far East Organization\n6. **Mitchell Chan** - Sales Engineer at Splunk\n7. **David Bochsler** - Vice President of Sales (Asia Pacific & Japan) at KnowBe4\n8. **Patricia A.** - Sales Manager ASEAN at Siemens\n9. **Zhiming Fong** - Director Strategic Partnerships & Sales, APAC at Amadeus\n10. **Daniel Ang** - Sales Executive at Far East Organization\n11. **Annabel Chang** - Sales Development Manager (APJ) at KnowBe4\n12. **Lawrence Koh** - Assistant General Manager, Managed Services and Solution Sales at StarHub\n13. **Kimberly Pang** - Sales Manager at StarHub\n14. **Zheng Teo** - Sales Manager at Far East Hospitality Management (S) Pte Ltd\n15. **Marie-Frédérique Romain** - Head of Sales Pacific at Airbus Defence and Space\n16. **Audrey Seow** - Cluster Director of Sales and Marketing at Marriott International Hotels, Inc.\n17. **Vinny Kim** - Sales Advisor at StarHub\n18. **Anna Chiang** - Sales Executive at Bloomberg Businessweek\n19. **Clarence Lau** - Assistant Sales Manager at Anritsu\n20. **Vincent Ang** - Sales Manager at Siemens\n\nThis is just a selection of the sales professionals in Singapore. If you need more names or specific details, let me know!')]

# %%
agent.invoke({"input": "Identify companies that are attending finance related events."})
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_query_checker` with `{'query': "SELECT DISTINCT c.company_name, c.company_industry, e.event_name, e.event_industry \nFROM company c \nJOIN event e ON c.relation_to_event = 'partner' OR c.relation_to_event = 'sponsor' \nWHERE e.event_industry = 'Finance';"}`
#
#
# ```sql
# SELECT DISTINCT c.company_name, c.company_industry, e.event_name, e.event_industry
# FROM company c
# JOIN event e ON c.relation_to_event IN ('partner', 'sponsor')
# WHERE e.event_industry = 'Finance';
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT DISTINCT c.company_name, c.company_industry, e.event_name, e.event_industry \nFROM company c \nJOIN event e ON c.relation_to_event IN ('partner', 'sponsor') \nWHERE e.event_industry = 'Finance';"}`
#
#
# [('Debeaurepairewines.Com', None, 'Commodity Trading Week APAC', 'Finance'), ('Aleios', 'Software Development', 'Accounting & Business Show Asia 2024', 'Finance'), ('Space Ambition', 'Space Research And Technology', 'Accounting & Business Show Asia 2024', 'Finance'), ('Deal', 'Information Technology & Services', 'Accounting & Business Show Asia 2024', 'Finance'), ('Enterprise Singapore', 'Government Administration', 'Accounting & Business Show Asia 2024', 'Finance'), ('Veoci', 'Software Development', 'Commodity Trading Week APAC', 'Finance'), ('Teledyne Advanced Electronic Solutions', 'Appliances, Electrical, And Electronics Manufacturing,  Circuit Card Assemblies,  Microelectronics Packaging Solutions,  Mechanical Box And Backplane Assemblies,  Hybrid Microcircuits And Multichip Modules,  Functional Testing,  Rf Microelectronics Packaging,  Turnkey Material Management', 'Accounting & Business Show Asia 2024', 'Finance'), ('Pacific Telecommunications Council (Ptc)', 'Telecommunications', 'Commodity Trading Week APAC', 'Finance'), ('Sgx Regco', 'Financial Services,  Finance,  Finance General,  Other Capital Markets/Institutions', 'Accounting & Business Show Asia 2024', 'Finance'), ('Marex', 'Financial Services', 'Commodity Trading Week APAC', 'Finance'), ('Yurieducationproject.Com', None, 'Accounting & Business Show Asia 2024', 'Finance'), ('Truescope', 'Public Relations And Communications Services', 'Accounting & Business Show Asia 2024', 'Finance'), ('Beyond', 'Design,  Software General,  Branded Content,  Software,  Online Media,  Earned Media Optimization,  Social Media,  Conversation Analytics,  Digital Creative,  Consulting,  Mobile', 'Commodity Trading Week APAC', 'Finance'), ('Fit2Flyga.Com', None, 'Commodity Trading Week APAC', 'Finance'), ('Uplift Inc.', 'Financial Services', 'Commodity Trading Week APAC', 'Finance'), ('Horwath Htl Atlanta', 'Hospitality', 'Accounting & Business Show Asia 2024', 'Finance'), ('Teacusa.Com', None, 'Commodity Trading Week APAC', 'Finance'), ('Accor Plus', 'Hospitality,  Hospitality General,  Hotel Discounts | Hotel Loyality Marketing | Sales Management |', 'Accounting & Business Show Asia 2024', 'Finance'), ('Vast', 'Defense And Space Manufacturing', 'Commodity Trading Week APAC', 'Finance'), ('Semrush', 'Software,  Software Development,  Business Intelligence (Bi) Software,  Analytics,  Search Engine Analysis,  Software Development & Design,  Data And Analytics,  Internet Marketing,  Content Marketing,  Competitive Analysis,  Sales And Marketing,  Seo/Sem,  Digital Marketing,  Market Research, ...', 'Commodity Trading Week APAC', 'Finance'), ('Sherpa Adventure Gear', 'Retail,  Retail Apparel And Fashion', 'Commodity Trading Week APAC', 'Finance'), ('Instapod.Co', None, 'Accounting & Business Show Asia 2024', 'Finance'), ('Cxloyalty', 'Travel Arrangements', 'Accounting & Business Show Asia 2024', 'Finance'), ('Evfly', 'Airlines And Aviation', 'Accounting & Business Show Asia 2024', 'Finance'), ('Agnikul Cosmos', 'Defense And Space Manufacturing', 'Accounting & Business Show Asia 2024', 'Finance'), ('Informa Markets-Healthcare', 'Events Services', 'Accounting & Business Show Asia 2024', 'Finance'), ('Excelpoint Systems-Australia/Newzealand', 'Semiconductors', 'Accounting & Business Show Asia 2024', 'Finance'), ('Hackuity', 'Computer And Network Security', 'Accounting & Business Show Asia 2024', 'Finance'), ('Oup.Com', 'Book And Periodical Publishing,  Media & Internet General,  Media & Internet', 'Accounting & Business Show Asia 2024', 'Finance'), ('Futurelog Ag', 'Software Development,  Consumer Electronics & Computers Retail,  Retail', 'Accounting & Business Show Asia 2024', 'Finance'), ('Centre For Cyber Security', 'Computer And Network Security', 'Commodity Trading Week APAC', 'Finance'), ('Value Creed', 'Oil And Gas', 'Commodity Trading Week APAC', 'Finance'), ('Sc Capital Partners, Inc.', 'Investment Banking', 'Commodity Trading Week APAC', 'Finance'), ('Cardinal Spellman High Schoo ...
#
# | Company Name                          | Company Industry                                                                 | Event Name                          | Event Industry |
# |---------------------------------------|----------------------------------------------------------------------------------|-------------------------------------|----------------|
# | Debeaurepairewines.Com                | None                                                                             | Commodity Trading Week APAC         | Finance        |
# | Aleios                                | Software Development                                                              | Accounting & Business Show Asia 2024| Finance        |
# | Space Ambition                        | Space Research And Technology                                                    | Accounting & Business Show Asia 2024| Finance        |
# | Deal                                  | Information Technology & Services                                                | Accounting & Business Show Asia 2024| Finance        |
# | Enterprise Singapore                  | Government Administration                                                         | Accounting & Business Show Asia 2024| Finance        |
# | Veoci                                 | Software Development                                                              | Commodity Trading Week APAC         | Finance        |
# | Teledyne Advanced Electronic Solutions | Appliances, Electrical, And Electronics Manufacturing, Circuit Card Assemblies   | Accounting & Business Show Asia 2024| Finance        |
# | Pacific Telecommunications Council (Ptc)| Telecommunications                                                              | Commodity Trading Week APAC         | Finance        |
# | Sgx Regco                             | Financial Services, Finance, Finance General, Other Capital Markets/Institutions | Accounting & Business Show Asia 2024| Finance        |
# | Marex                                 | Financial Services                                                                | Commodity Trading Week APAC         | Finance        |
# | 100 Women In Finance                  | Financial Services                                                                | Commodity Trading Week APAC         | Finance        |
# | Federal Reserve Bank Of Atlanta       | Financial Services                                                                | Accounting & Business Show Asia 2024| Finance        |
# | Chubb                                 | Insurance                                                                         | Accounting & Business Show Asia 2024| Finance        |
# | Accelya Group                         | Financial Services                                                                | Accounting & Business Show Asia 2024| Finance        |
# | Pro-Invest Group                      | Investment Management, Finance General, Real Estate Development, Finance         | Commodity Trading Week APAC         | Finance        |
#
# This is just a selection of companies attending finance-related events. If you need more specific information or additional companies, feel free to ask!
#
# > Finished chain.
# {'input': 'Identify companies that are attending finance related events.',
#  'output': 'Here are some companies that are attending finance-related events:\n\n| Company Name                          | Company Industry                                                                 | Event Name                          | Event Industry |\n|---------------------------------------|----------------------------------------------------------------------------------|-------------------------------------|----------------|\n| Debeaurepairewines.Com                | None                                                                             | Commodity Trading Week APAC         | Finance        |\n| Aleios                                | Software Development                                                              | Accounting & Business Show Asia 2024| Finance        |\n| Space Ambition                        | Space Research And Technology                                                    | Accounting & Business Show Asia 2024| Finance        |\n| Deal                                  | Information Technology & Services                                                | Accounting & Business Show Asia 2024| Finance        |\n| Enterprise Singapore                  | Government Administration                                                         | Accounting & Business Show Asia 2024| Finance        |\n| Veoci                                 | Software Development                                                              | Commodity Trading Week APAC         | Finance        |\n| Teledyne Advanced Electronic Solutions | Appliances, Electrical, And Electronics Manufacturing, Circuit Card Assemblies   | Accounting & Business Show Asia 2024| Finance        |\n| Pacific Telecommunications Council (Ptc)| Telecommunications                                                              | Commodity Trading Week APAC         | Finance        |\n| Sgx Regco                             | Financial Services, Finance, Finance General, Other Capital Markets/Institutions | Accounting & Business Show Asia 2024| Finance        |\n| Marex                                 | Financial Services                                                                | Commodity Trading Week APAC         | Finance        |\n| 100 Women In Finance                  | Financial Services                                                                | Commodity Trading Week APAC         | Finance        |\n| Federal Reserve Bank Of Atlanta       | Financial Services                                                                | Accounting & Business Show Asia 2024| Finance        |\n| Chubb                                 | Insurance                                                                         | Accounting & Business Show Asia 2024| Finance        |\n| Accelya Group                         | Financial Services                                                                | Accounting & Business Show Asia 2024| Finance        |\n| Pro-Invest Group                      | Investment Management, Finance General, Real Estate Development, Finance         | Commodity Trading Week APAC         | Finance        |\n\nThis is just a selection of companies attending finance-related events. If you need more specific information or additional companies, feel free to ask!'}

# %%
agent.invoke({"input": "Identify companies that are attending banking related events."})
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_query_checker` with `{'query': "SELECT DISTINCT c.company_name, c.company_industry, e.event_name, e.event_industry \nFROM company c \nJOIN event e ON c.relation_to_event = 'partner' OR c.relation_to_event = 'sponsor' \nWHERE e.event_industry ILIKE '%banking%' OR e.event_description ILIKE '%banking%' \nORDER BY c.company_name;"}`
#
#
# ```sql
# SELECT DISTINCT c.company_name, c.company_industry, e.event_name, e.event_industry
# FROM company c
# JOIN event e ON c.relation_to_event IN ('partner', 'sponsor')
# WHERE e.event_industry ILIKE '%banking%' OR e.event_description ILIKE '%banking%'
# ORDER BY c.company_name;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT DISTINCT c.company_name, c.company_industry, e.event_name, e.event_industry \nFROM company c \nJOIN event e ON c.relation_to_event IN ('partner', 'sponsor') \nWHERE e.event_industry ILIKE '%banking%' OR e.event_description ILIKE '%banking%' \nORDER BY c.company_name;"}`
#
#
# [('#Xcelerai', 'Software Development', 'Seamless Asia 2025', 'Other'), ('100 Women In Finance', 'Financial Services', 'Seamless Asia 2025', 'Other'), ('15Below', 'Airlines And Aviation', 'Seamless Asia 2025', 'Other'), ('1Pointfive', 'Environmental Services', 'Seamless Asia 2025', 'Other'), ('2E Systems', 'Business Consulting And Services', 'Seamless Asia 2025', 'Other'), ('3Ipk', 'It Services And It Consulting', 'Seamless Asia 2025', 'Other'), ('Abomis Innovations Inc.', 'Airlines And Aviation', 'Seamless Asia 2025', 'Other'), ('Abs Global', 'Biotechnology Research', 'Seamless Asia 2025', 'Other'), ('Abs Group', 'Business Consulting And Services', 'Seamless Asia 2025', 'Other'), ('Abs Kids', 'Mental Health Care,  Hospitals & Clinics,  Applied Behavioral Analysis For Autism Spectrum Therapy,  Healthcare,  Speech Therapy,  Diagnostic Evaluations,  Psychotherapy,  Occupational Therapy,  Individual Therapy', 'Seamless Asia 2025', 'Other'), ('Accelya Group', 'Financial Services', 'Seamless Asia 2025', 'Other'), ('Accesswireless.Com', None, 'Seamless Asia 2025', 'Other'), ('Accor', 'Hospitality', 'Seamless Asia 2025', 'Other'), ('Accor Plus', 'Hospitality,  Hospitality General,  Hotel Discounts | Hotel Loyality Marketing | Sales Management |', 'Seamless Asia 2025', 'Other'), ('Acn Newswire', 'Broadcast Media Production And Distribution', 'Seamless Asia 2025', 'Other'), ('Acnavergers.Com', None, 'Seamless Asia 2025', 'Other'), ('Acronis', 'Software Development', 'Seamless Asia 2025', 'Other'), ('Adventnet, Inc', 'Business Services,  Information Technology And Services', 'Seamless Asia 2025', 'Other'), ('Adzaps', 'Advertising Services', 'Seamless Asia 2025', 'Other'), ('Aeroclass.Org', 'Airlines And Aviation', 'Seamless Asia 2025', 'Other'), ('Aeropay', 'Financial Services,  Mobile Payments,  Fintech,  Payments,  Fintech,  Local Shopping,  Commerce And Shopping,  Payment Processing ,  In-Store Payments,  Mobile,  Mobile App,  Ach,  Software,  Small Business', 'Seamless Asia 2025', 'Other'), ('Aeropaye', 'Airlines And Aviation', 'Seamless Asia 2025', 'Other'), ('Aeroprime Group', 'Airlines And Aviation', 'Seamless Asia 2025', 'Other'), ('Aerothai-Aeronautical Radio Of Thailand Ltd', 'Aviation And Aerospace Component Manufacturing', 'Seamless Asia 2025', 'Other'), ('Agnikul Cosmos', 'Defense And Space Manufacturing', 'Seamless Asia 2025', 'Other'), ('Ahrefs', 'Technology, Information And Internet', 'Seamless Asia 2025', 'Other'), ('Ailytic', 'Software Development', 'Seamless Asia 2025', 'Other'), ('Ailytics', 'It Services And It Consulting', 'Seamless Asia 2025', 'Other'), ('Air-Way Global Manufacturing Company', 'Construction', 'Seamless Asia 2025', 'Other'), ('Airalo', 'Telecommunications', 'Seamless Asia 2025', 'Other'), ('Airbus Defence And Space', 'Aviation And Aerospace Component Manufacturing', 'Seamless Asia 2025', 'Other'), ('Airfree', 'Manufacturing', 'Seamless Asia 2025', 'Other'), ('Airfree', 'Software Development,  Software', 'Seamless Asia 2025', 'Other'), ('Airsiders', 'Airlines And Aviation', 'Seamless Asia 2025', 'Other'), ('Alcatel Submarine Networks', 'Telecommunications', 'Seamless Asia 2025', 'Other'), ('Aleios', 'Software Development', 'Seamless Asia 2025', 'Other'), ('Alibaba.Com', 'International Trade And Development', 'Seamless Asia 2025', 'Other'), ('Allfly', 'Travel Arrangements', 'Seamless Asia 2025', 'Other'), ('Alshaya Group', 'Retail', 'Seamless Asia 2025', 'Other'), ('Alto-Shaam, Inc.', 'Food And Beverage Services', 'Seamless Asia 2025', 'Other'), ('Amadeus', 'Airlines And Aviation', 'Seamless Asia 2025', 'Other'), ('Amazon Web Services (Aws)', 'It Services And It Consulting', 'Seamless Asia 2025', 'Other'), ('American Board Of Surgery', 'Hospitals And Health Care', 'Seamless Asia 2025', 'Other'), ('American Writers & Artists Institute', 'Writing And Editing', 'Seamless Asia 2025', 'Other'), ('Amphenol Tpc Wire & Cable', 'Appliances, Electrical, And Electronics Manufacturing', 'Seamless Asia 2025', 'Othe ...
#
# | Company Name                       | Company Industry                                   | Event Name                | Event Industry |
# |------------------------------------|---------------------------------------------------|---------------------------|----------------|
# | 100 Women In Finance               | Financial Services                                 | Seamless Asia 2025       | Other          |
# | Accelya Group                      | Financial Services                                 | Seamless Asia 2025       | Other          |
# | Aeropay                            | Financial Services, Mobile Payments, Fintech      | Seamless Asia 2025       | Other          |
# | Bloomberg                          | Financial Services                                 | Seamless Asia 2025       | Other          |
# | Federal Reserve Bank Of Atlanta    | Financial Services                                 | Seamless Asia 2025       | Other          |
# | Itfa Americas (Amrc)              | Financial Services                                 | Seamless Asia 2025       | Other          |
# | Marex Solutions                    | Financial Services                                 | Seamless Asia 2025       | Other          |
# | Monetary Authority Of Singapore    | Banking, Finance, Financial Services               | Seamless Asia 2025       | Other          |
# | Pro-Invest Group                   | Investment Management, Finance General             | Seamless Asia 2025       | Other          |
# | Salter Brothers                    | Financial Services                                 | Seamless Asia 2025       | Other          |
# | Trident                            | Hospitality, Financial Services                    | Seamless Asia 2025       | Other          |
# | Zurich Insurance                   | Insurance                                          | Seamless Asia 2025       | Other          |
#
# These companies are involved in various aspects of financial services and are participating in the "Seamless Asia 2025" event, which is categorized under "Other" industry but includes banking-related themes.
#
# > Finished chain.
# {'input': 'Identify companies that are attending banking related events.',
#  'output': 'Here are some companies that are attending banking-related events:\n\n| Company Name                       | Company Industry                                   | Event Name                | Event Industry |\n|------------------------------------|---------------------------------------------------|---------------------------|----------------|\n| 100 Women In Finance               | Financial Services                                 | Seamless Asia 2025       | Other          |\n| Accelya Group                      | Financial Services                                 | Seamless Asia 2025       | Other          |\n| Aeropay                            | Financial Services, Mobile Payments, Fintech      | Seamless Asia 2025       | Other          |\n| Bloomberg                          | Financial Services                                 | Seamless Asia 2025       | Other          |\n| Federal Reserve Bank Of Atlanta    | Financial Services                                 | Seamless Asia 2025       | Other          |\n| Itfa Americas (Amrc)              | Financial Services                                 | Seamless Asia 2025       | Other          |\n| Marex Solutions                    | Financial Services                                 | Seamless Asia 2025       | Other          |\n| Monetary Authority Of Singapore    | Banking, Finance, Financial Services               | Seamless Asia 2025       | Other          |\n| Pro-Invest Group                   | Investment Management, Finance General             | Seamless Asia 2025       | Other          |\n| Salter Brothers                    | Financial Services                                 | Seamless Asia 2025       | Other          |\n| Trident                            | Hospitality, Financial Services                    | Seamless Asia 2025       | Other          |\n| Zurich Insurance                   | Insurance                                          | Seamless Asia 2025       | Other          |\n\nThese companies are involved in various aspects of financial services and are participating in the "Seamless Asia 2025" event, which is categorized under "Other" industry but includes banking-related themes.'}

# %%
agent.invoke({"input": "Identify companies that are attending Oil & Gas related events."})
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_query_checker` with `{'query': "SELECT DISTINCT c.company_name, c.company_industry, e.event_name, e.event_description \nFROM company c \nJOIN event e ON c.relation_to_event = 'partner' OR c.relation_to_event = 'sponsor' \nWHERE e.event_industry ILIKE '%Oil & Gas%';"}`
#
#
# ```sql
# SELECT DISTINCT c.company_name, c.company_industry, e.event_name, e.event_description
# FROM company c
# JOIN event e ON c.relation_to_event IN ('partner', 'sponsor')
# WHERE e.event_industry ILIKE '%Oil & Gas%';
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT DISTINCT c.company_name, c.company_industry, e.event_name, e.event_description \nFROM company c \nJOIN event e ON c.relation_to_event IN ('partner', 'sponsor') \nWHERE e.event_industry ILIKE '%Oil & Gas%';"}`
#
#
# It appears that there are currently no companies listed as attending events related to the Oil & Gas industry in the database. If you have any other queries or need information on a different topic, feel free to ask!
#
# > Finished chain.
# {'input': 'Identify companies that are attending Oil & Gas related events.',
#  'output': 'It appears that there are currently no companies listed as attending events related to the Oil & Gas industry in the database. If you have any other queries or need information on a different topic, feel free to ask!'}

# %%
agent.invoke({"input": "Find all sales people working in Singapore"})
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_query_checker` with `{'query': 'SELECT DISTINCT job_title FROM people;'}`
# responded: It seems that the database does not have a specific column for job titles related to "sales" in the people table. However, I can search for people based on their job titles that might be related to sales, such as "Sales Representative," "Sales Manager," etc.
#
# Let me first check the job titles available in the people table to see if there are any relevant titles related to sales. I'll proceed with that.
#
# ```sql
# SELECT DISTINCT job_title FROM people;
# ```
# Invoking: `sql_db_query` with `{'query': 'SELECT DISTINCT job_title FROM people;'}`
#
#
# [('Property Consultant',), ('Area Director, Malaysia, Thailand and Brunei',), ('SVP Strategic Initatives - Europe CarbonClick',), ('Procurement',), ('customer manager',), ('Vice president sales',), ('Regional Manager @ Electrolux Professional',), ('Slocum Glider Commercial Sales Manager Teledyne Marine Vehicles',), ('Executive Events',), ('PDJ @ Singapore Tourism Board',), ('Planning Manager - Inventory Management Hewlett Packard Enterprise',), ('Data Project Supervisor',), ('Senior Manager of Transportation and Distribution',), ('Country Leader Sales Austria @ Nordcloud, an IBM Company',), ('Vice President of Talent Strategies ST Engineering North America',), ('Regional Sales Representative',), ('Account Executive Credly',), ('Sales Supporter',), ('Vice President, Global Channel Distribution',), ('영업이사 @ VIAVI Solutions',), ('Head Of Business Development_Asia Pacific Region',), ('Leasing Manager',), ('Vice President Strategy Business Development',), ('Event Manager @ Pharma & MedTech Business Intelligence',), ('Revenue Optimization Manager',), ('Senior Account Manager @ Trade Data Monitor LLC',), (None,), ('MSS Localization Supply Chain Manager',), ('consultant',), ('Analista de planificación',), ('Senior Logistics Coordinator',), ('Assistant Controller Koppert Cress',), ('Member- Standards Working Group Enterprise Singapore',), ('Assistant, Events',), ('Chef de Réception @ IHG Hotels & Resorts',), ('Security Network Consulting Engineer-3 Aryaka',), ('Operation executive',), ('Senior Sales Director, Media',), ('Business Develpoment Manager',), ('Director, Catering and Event Services',), ('Logistics Supervisor',), ('Responsable Supply Chain',), ('Process Quality Engineer Contec Holdings',), ('Business Development Officer',), ('Core Data Scientist impact.com',), ('Planning Specialist, Technology Consultant',), ('International Business Development Representative',), ('Contract Manager Global MSI',), ('Supplier Management',), ('VP of Meteorology at AG2',), ('Superintendent EXA GROUP',), ('Director of Sales-Beauty',), ('Junior administrative accountant EXA MP',), ('Product and Business Development Specialist',), ('16 years 2 months in role 16 years 2 months in company',), ('Regional Sales Executive',), ('Human Resources Business Partner Kacific Broadband Satellites Group',), ('EXECUTIVE HEAD CHEF',), ('Law',), ('Administrative Officer',), ('Development Director',), ('Sr. Consulting Engineer',), ('Reg Sales Manager',), ('Regional Distribution Manager',), ('Assistant Director (Aviation Relations & Systems) Ministry of Transport, Singapore',), ('Global Account Operation Manager Hewlett Packard Enterprise',), ('Vice President @ SGX RegCo',), ('Enterprise Account Executive - APAC Credly by Pearson',), ('Area Director, Indonesia @ Singapore Tourism Board',), ('Sales Executive Bloomberg Businessweek',), ('Video Production Manager ISACA',), ('Corporate Support Manager Trilogy Hotels',), ('National Director of Sales and Marketing',), ('Director, Amazon Logistics',), ('Claims verification officer',), ('Inside Sales Representative',), ('SIS Technical Manager Emerson Process Management Asia Pacific Pte Ltd',), ('Regional Sales Manager-MEA',), ('Senior Functional Analyst',), ('Area Vice President',), ('Cybersecurity Engineer Hackuity',), ('Sales and Marketing Manager Baltics Professional Food Service Equipment',), ('material handler',), ('Cluster Assistant Director of Marketing Communications Marriott International',), ('Supervises @ Singapore Tourism Board',), ('Sales Order Processing Specialist',), ('Deputy Director, Tourism Concept Development',), ('Head of Logistic Operations Germany @ Airbus Defence and Space',), ('Area Vice President of Sales, EMEA impact.com',), ('Projectleider werktuigbouwkundige installaties',), ('Enterprise Account Executive DACH at LastPass',), ('iOS App Developer',), ('Senior National Account Manager',), ('Visitor Information and Feedback Officer (FT)',), ('Business Process Analyst',), ('Associate-Corporate Sales', ...
# Invoking: `sql_db_query_checker` with `{'query': "SELECT first_name, last_name, job_title, person_city, person_country FROM people WHERE job_title ILIKE '%Sales%' AND person_country = 'Singapore';"}`
# responded: The job titles related to sales in the database include:
#
# - Sales Executive
# - Sales Manager
# - Sales Consultant
# - Sales Engineer
# - Sales Representative
# - Sales Director
# - Sales Account Manager
# - Sales Support
# - Sales Operations
# - Sales Development Representative
# - Sales Coordinator
# - Sales Marketing Executive
# - Sales and Marketing Manager
# - Sales and Business Development Manager
#
# Now, I will search for people with these job titles who are located in Singapore. Let's proceed with that query.
#
# ```sql
# SELECT first_name, last_name, job_title, person_city, person_country FROM people WHERE job_title ILIKE '%Sales%' AND person_country = 'Singapore';
# ```
# Invoking: `sql_db_query_checker` with `{'query': "SELECT first_name, last_name, job_title, person_city, person_country FROM people WHERE job_title ILIKE '%Sales%' AND person_city = 'Singapore';"}`
# responded: The job titles related to sales in the database include:
#
# - Sales Executive
# - Sales Manager
# - Sales Consultant
# - Sales Engineer
# - Sales Representative
# - Sales Director
# - Sales Account Manager
# - Sales Support
# - Sales Operations
# - Sales Development Representative
# - Sales Coordinator
# - Sales Marketing Executive
# - Sales and Marketing Manager
# - Sales and Business Development Manager
#
# Now, I will search for people with these job titles who are located in Singapore. Let's proceed with that query.
#
# ```sql
# SELECT first_name, last_name, job_title, person_city, person_country FROM people WHERE job_title ILIKE '%Sales%' AND person_city = 'Singapore';
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT first_name, last_name, job_title, person_city, person_country FROM people WHERE job_title ILIKE '%Sales%' AND person_country = 'Singapore';"}`
#
#
# [('Koh', 'Jing How', 'Enterprise Sales SEA PayPal', None, 'Singapore'), ('Eric', 'Chan', 'Sales Manager', 'Singapore', 'Singapore'), ('Poh', '\\-', 'Land Transfer and Land Sales @ Singapore Land Authority (SLA)', 'Singapore', 'Singapore'), ('Cao', 'Li', 'Sales', 'Singapore', 'Singapore'), ('Melissa', 'Wong', 'Sales Administrative Executive', 'Singapore', 'Singapore'), ('Mitchell', 'Chan', 'Sales Engineer Splunk', None, 'Singapore'), ('David', 'Bochsler', 'Vice President of Sales (Asia Pacific & Japan) KnowBe4', None, 'Singapore'), ('Patricia', 'A.', 'Sales Manager ASEAN Siemens', 'Singapore', 'Singapore'), ('Zhiming', 'Fong', 'Director Strategic Partnerships & Sales, APAC Amadeus', None, 'Singapore'), ('Daniel', 'Ang', 'Sales Executive', 'Singapore', 'Singapore'), ('Annabel', 'Chang', 'Sales Development Manager (APJ) KnowBe4', None, 'Singapore'), ('Lawrence', 'Koh', 'Assistant General Manager, Managed Services and Solution Sales', 'Singapore', 'Singapore'), ('Kimberly', 'Pang', 'Sales Manager', 'Singapore', 'Singapore'), ('Zheng', 'Teo', 'Sales Manager', 'Singapore', 'Singapore'), ('Marie-Frédérique', 'Romain', 'Head of Sales Pacific', 'Singapore', 'Singapore'), ('Audrey', 'Seow', 'Cluster Director of Sales and Marketing, JW Marriott Singapore and The St Regis Singapore Marriott International', None, 'Singapore'), ('Vinny', 'Kim', 'Sales Advisor', 'Singapore', 'Singapore'), ('Anna', 'Chiang', 'Sales Executive Bloomberg Businessweek', None, 'Singapore'), ('Clarence', 'Lau', 'Assistant Sales Manager', 'Singapore', 'Singapore'), ('Vincent', 'Ang', 'Sales Manager Siemens', None, 'Singapore'), ('Alvin', 'Xu', 'Assistant Director of Sales', 'Singapore', 'Singapore'), ('Ericka', 'T.', 'Regional Sales Manager - Indonesia Splunk', None, 'Singapore'), ('Koon', 'Tay', 'Head, Government Sales', 'Singapore', 'Singapore'), ('David', 'Lee', 'Assistant Director Of Sales', 'Singapore', 'Singapore'), ('Josephine', 'Lim', 'Area Director of Sales and Marketing', 'Singapore', 'Singapore'), ('Kershawn', 'Liau', 'Graduate Presales Hewlett Packard Enterprise', 'Singapore', 'Singapore'), ('Lock', 'Hao', 'Assistant Sales Manager', 'Singapore', 'Singapore'), ('Jun', 'Ang', 'Sales Specialist', 'Singapore', 'Singapore'), ('Joel', 'Lim Xin Yong', 'Salesperson Hewlett Packard Enterprise', 'Singapore', 'Singapore'), ('Fenny', 'Tan', 'Senior Sales Manager', 'Singapore', 'Singapore'), ('Gary', 'T.', 'Commercial Sales Executive Amadeus', None, 'Singapore'), ('Greta', 'Yap', 'Regional Sales Manager Darktrace', 'Singapore', 'Singapore'), ('Satish', 'Khanna', 'Director Sales Siemens Energy - Power & Gas', 'Singapore', 'Singapore'), ('Ericka', 'T.', 'Regional Sales Manager - Indonesia Splunk', None, 'Singapore'), ('Keng', 'Tan', 'Presales Director', 'Singapore', 'Singapore'), ('Shabab', 'MK', 'APAC Ecosystem Sales Manager Hewlett Packard Enterprise', None, 'Singapore'), ('Dave', 'Ong', 'Sales Consultant', 'Singapore', 'Singapore'), ('shikai', 'wang', 'Sales excutive Siemens', None, 'Singapore'), ('Shruti', 'More', 'Renewals Sales Specialist (ANZ & INDIA) SUSE', None, 'Singapore'), ('Hpyo', 'Paing', 'Senior Manager Sales Operations', 'Singapore', 'Singapore'), ('Sandy', 'Koh', 'Assistant Director of Sales, Business Travel', 'Singapore', 'Singapore'), ('Kia', 'Fua', 'Head of Sales Enablement Apj', 'Singapore', 'Singapore'), ('Yak', 'Ng', 'Sales Manager Mitsubishi Electric', None, 'Singapore'), ('Alvin', 'Xu', 'Assistant Director of Sales', 'Singapore', 'Singapore'), ('Mary', 'L.', 'Director Channel Sales (Asia) BlackBerry', None, 'Singapore'), ('Hwee', 'Ng', 'Senior Sales Manager Marriott International', None, 'Singapore'), ('Angela', 'YAP', 'Sales Representative Hewlett-Packard', None, 'Singapore'), ('Klarissa', 'Chia', 'Sales Coordinator', 'Singapore', 'Singapore'), ('Jun', 'Ang', 'Sales Specialist', 'Singapore', 'Singapore'), ('Gloria', 'Hendrix', 'Salesperson Bloomberg News', 'Singapore', 'Singapore'), ('PB', None, 'Director of Sales', 'Singapore', 'Singapore'),  ...
# Invoking: `sql_db_query` with `{'query': "SELECT first_name, last_name, job_title, person_city, person_country FROM people WHERE job_title ILIKE '%Sales%' AND person_city = 'Singapore';"}`
#
#
# [('Eric', 'Chan', 'Sales Manager', 'Singapore', 'Singapore'), ('Poh', '\\-', 'Land Transfer and Land Sales @ Singapore Land Authority (SLA)', 'Singapore', 'Singapore'), ('Cao', 'Li', 'Sales', 'Singapore', 'Singapore'), ('Melissa', 'Wong', 'Sales Administrative Executive', 'Singapore', 'Singapore'), ('Patricia', 'A.', 'Sales Manager ASEAN Siemens', 'Singapore', 'Singapore'), ('Daniel', 'Ang', 'Sales Executive', 'Singapore', 'Singapore'), ('Lawrence', 'Koh', 'Assistant General Manager, Managed Services and Solution Sales', 'Singapore', 'Singapore'), ('Kimberly', 'Pang', 'Sales Manager', 'Singapore', 'Singapore'), ('Zheng', 'Teo', 'Sales Manager', 'Singapore', 'Singapore'), ('Fereen', 'Tan', 'Sales Manager', 'Singapore', None), ('Marie-Frédérique', 'Romain', 'Head of Sales Pacific', 'Singapore', 'Singapore'), ('Vinny', 'Kim', 'Sales Advisor', 'Singapore', 'Singapore'), ('Clarence', 'Lau', 'Assistant Sales Manager', 'Singapore', 'Singapore'), ('Ramkumar', 'Balaguru', 'Presales Manager', 'Singapore', None), ('Alvin', 'Xu', 'Assistant Director of Sales', 'Singapore', 'Singapore'), ('Koon', 'Tay', 'Head, Government Sales', 'Singapore', 'Singapore'), ('David', 'Lee', 'Assistant Director Of Sales', 'Singapore', 'Singapore'), ('Josephine', 'Lim', 'Area Director of Sales and Marketing', 'Singapore', 'Singapore'), ('Kershawn', 'Liau', 'Graduate Presales Hewlett Packard Enterprise', 'Singapore', 'Singapore'), ('Lock', 'Hao', 'Assistant Sales Manager', 'Singapore', 'Singapore'), ('Jun', 'Ang', 'Sales Specialist', 'Singapore', 'Singapore'), ('Joel', 'Lim Xin Yong', 'Salesperson Hewlett Packard Enterprise', 'Singapore', 'Singapore'), ('Fenny', 'Tan', 'Senior Sales Manager', 'Singapore', 'Singapore'), ('Hong', 'Zhiwei', 'Sales Director', 'Singapore', None), ('Jain', 'Abhineet', 'Director of Sales and Business Development, Asia Pacific', 'Singapore', None), ('Greta', 'Yap', 'Regional Sales Manager Darktrace', 'Singapore', 'Singapore'), ('Satish', 'Khanna', 'Director Sales Siemens Energy - Power & Gas', 'Singapore', 'Singapore'), ('Keng', 'Tan', 'Presales Director', 'Singapore', 'Singapore'), ('Dave', 'Ong', 'Sales Consultant', 'Singapore', 'Singapore'), ('Hpyo', 'Paing', 'Senior Manager Sales Operations', 'Singapore', 'Singapore'), ('Justin', 'Ong', 'Senior Sales and Leasing Manager', 'Singapore', None), ('Zaccheus', 'Sabai', 'International Channel Sales @ KnowBe4', 'Singapore', None), ('Sandy', 'Koh', 'Assistant Director of Sales, Business Travel', 'Singapore', 'Singapore'), ('Kia', 'Fua', 'Head of Sales Enablement Apj', 'Singapore', 'Singapore'), ('Alvin', 'Xu', 'Assistant Director of Sales', 'Singapore', 'Singapore'), ('Vipin', 'Jain', 'Regional Sales Director', 'Singapore', None), ('Klarissa', 'Chia', 'Sales Coordinator', 'Singapore', 'Singapore'), ('Jun', 'Ang', 'Sales Specialist', 'Singapore', 'Singapore'), ('Gloria', 'Hendrix', 'Salesperson Bloomberg News', 'Singapore', 'Singapore'), ('PB', None, 'Director of Sales', 'Singapore', 'Singapore'), ('Titus', 'Inocencio', 'Cluster Assistant Director of Sales', 'Singapore', 'Singapore'), ('Ashley', 'Hansen', 'Vice President, Sales & Distribution, Asia Pacific excluding China & South Asia Marriott International', 'Singapore', 'Singapore'), ('Lim', 'Nigel', 'Property Sales Consultant', 'Singapore', 'Singapore'), ('Ng', 'Wen', 'Cluster Sales Executive Marriott International', 'Singapore', 'Singapore'), ('Rene', 'Tan', 'Sales Director', 'Singapore', 'Singapore'), ('Nigel', 'Khoo', 'Assistant Director Of Sales', 'Singapore', None), ('Feo', 'Liu', 'property sales', 'Singapore', 'Singapore'), ('Charissa', 'Chiam', 'Director of Sales', 'Singapore', 'Singapore'), ('Janet', 'Liew', 'Inside Sales Representative', 'Singapore', 'Singapore'), ('Imelda', 'Zhang', 'Head of Service Sales Siemens', 'Singapore', 'Singapore'), ('David', 'Tang', 'Sales and Marketing', 'Singapore', 'Singapore'), ('Nije', 'Aw', 'Vacation Sales Consultant', 'Singapore', 'Singapore'), ('Poon', 'Mun', 'Regional Sales Director', 'Singapo ...
#
# | First Name | Last Name | Job Title | City | Country |
# |------------|-----------|-----------|------|---------|
# | Koh        | Jing How  | Enterprise Sales SEA PayPal | Singapore | Singapore |
# | Eric       | Chan      | Sales Manager | Singapore | Singapore |
# | Poh        | -         | Land Transfer and Land Sales @ Singapore Land Authority (SLA) | Singapore | Singapore |
# | Cao        | Li        | Sales | Singapore | Singapore |
# | Melissa    | Wong      | Sales Administrative Executive | Singapore | Singapore |
# | Mitchell   | Chan      | Sales Engineer Splunk | Singapore | Singapore |
# | David      | Bochsler  | Vice President of Sales (Asia Pacific & Japan) KnowBe4 | Singapore | Singapore |
# | Patricia   | A.        | Sales Manager ASEAN Siemens | Singapore | Singapore |
# | Zhiming    | Fong      | Director Strategic Partnerships & Sales, APAC Amadeus | Singapore | Singapore |
# | Daniel     | Ang       | Sales Executive | Singapore | Singapore |
# | Annabel    | Chang     | Sales Development Manager (APJ) KnowBe4 | Singapore | Singapore |
# | Lawrence   | Koh       | Assistant General Manager, Managed Services and Solution Sales | Singapore | Singapore |
# | Kimberly    | Pang      | Sales Manager | Singapore | Singapore |
# | Zheng      | Teo       | Sales Manager | Singapore | Singapore |
# | Marie-Frédérique | Romain | Head of Sales Pacific | Singapore | Singapore |
# | Vinny      | Kim       | Sales Advisor | Singapore | Singapore |
# | Clarence   | Lau       | Assistant Sales Manager | Singapore | Singapore |
# | Fenny      | Tan       | Senior Sales Manager | Singapore | Singapore |
# | Keng       | Tan       | Presales Director | Singapore | Singapore |
# | David      | Lee       | Assistant Director Of Sales | Singapore | Singapore |
# | Josephine  | Lim       | Area Director of Sales and Marketing | Singapore | Singapore |
# | Kershawn   | Liau      | Graduate Presales Hewlett Packard Enterprise | Singapore | Singapore |
# | Jun        | Ang       | Sales Specialist | Singapore | Singapore |
# | Joel       | Lim Xin Yong | Salesperson Hewlett Packard Enterprise | Singapore | Singapore |
# | Alvin      | Xu        | Assistant Director of Sales | Singapore | Singapore |
# | Koon       | Tay       | Head, Government Sales | Singapore | Singapore |
# | Satish     | Khanna    | Director Sales Siemens Energy - Power & Gas | Singapore | Singapore |
# | Kia        | Fua       | Head of Sales Enablement Apj | Singapore | Singapore |
# | Calvin     | Tham      | Sales Manager (Corporate Segment) | Singapore | Singapore |
# | Thomas     | Goldsbury | Presales Consultant | Singapore | Singapore |
# | PB         | Ong       | Director of Sales | Singapore | Singapore |
# | Aaron      | Kang      | Assistant Sales Manager | Singapore | Singapore |
# | Janet      | Liew      | Inside Sales Representative | Singapore | Singapore |
# | Du         | Alex      | Property sales | Singapore | Singapore |
# | Zach       | Lee       | Regional Channel Sales Director-SEA | Singapore | Singapore |
# | Siew       | Tay       | Sales Manager | Singapore | Singapore |
# | Imelda     | Zhang     | Head of Service Sales Siemens | Singapore | Singapore |
# | David      | Tang      | Sales and Marketing | Singapore | Singapore |
# | Nije       | Aw        | Vacation Sales Consultant | Singapore | Singapore |
# | Ashley     | Hansen    | Vice President, Sales & Distribution, Asia Pacific excluding China & South Asia Marriott International | Singapore | Singapore |
#
# This list includes various roles related to sales, from Sales Executives to Directors of Sales, all based in Singapore. If you need more specific information or further details, feel free to ask!
#
# > Finished chain.
# {'input': 'Find all sales people working in Singapore',
#  'output': 'Here are the sales professionals working in Singapore, along with their job titles:\n\n| First Name | Last Name | Job Title | City | Country |\n|------------|-----------|-----------|------|---------|\n| Koh        | Jing How  | Enterprise Sales SEA PayPal | Singapore | Singapore |\n| Eric       | Chan      | Sales Manager | Singapore | Singapore |\n| Poh        | -         | Land Transfer and Land Sales @ Singapore Land Authority (SLA) | Singapore | Singapore |\n| Cao        | Li        | Sales | Singapore | Singapore |\n| Melissa    | Wong      | Sales Administrative Executive | Singapore | Singapore |\n| Mitchell   | Chan      | Sales Engineer Splunk | Singapore | Singapore |\n| David      | Bochsler  | Vice President of Sales (Asia Pacific & Japan) KnowBe4 | Singapore | Singapore |\n| Patricia   | A.        | Sales Manager ASEAN Siemens | Singapore | Singapore |\n| Zhiming    | Fong      | Director Strategic Partnerships & Sales, APAC Amadeus | Singapore | Singapore |\n| Daniel     | Ang       | Sales Executive | Singapore | Singapore |\n| Annabel    | Chang     | Sales Development Manager (APJ) KnowBe4 | Singapore | Singapore |\n| Lawrence   | Koh       | Assistant General Manager, Managed Services and Solution Sales | Singapore | Singapore |\n| Kimberly    | Pang      | Sales Manager | Singapore | Singapore |\n| Zheng      | Teo       | Sales Manager | Singapore | Singapore |\n| Marie-Frédérique | Romain | Head of Sales Pacific | Singapore | Singapore |\n| Vinny      | Kim       | Sales Advisor | Singapore | Singapore |\n| Clarence   | Lau       | Assistant Sales Manager | Singapore | Singapore |\n| Fenny      | Tan       | Senior Sales Manager | Singapore | Singapore |\n| Keng       | Tan       | Presales Director | Singapore | Singapore |\n| David      | Lee       | Assistant Director Of Sales | Singapore | Singapore |\n| Josephine  | Lim       | Area Director of Sales and Marketing | Singapore | Singapore |\n| Kershawn   | Liau      | Graduate Presales Hewlett Packard Enterprise | Singapore | Singapore |\n| Jun        | Ang       | Sales Specialist | Singapore | Singapore |\n| Joel       | Lim Xin Yong | Salesperson Hewlett Packard Enterprise | Singapore | Singapore |\n| Alvin      | Xu        | Assistant Director of Sales | Singapore | Singapore |\n| Koon       | Tay       | Head, Government Sales | Singapore | Singapore |\n| Satish     | Khanna    | Director Sales Siemens Energy - Power & Gas | Singapore | Singapore |\n| Kia        | Fua       | Head of Sales Enablement Apj | Singapore | Singapore |\n| Calvin     | Tham      | Sales Manager (Corporate Segment) | Singapore | Singapore |\n| Thomas     | Goldsbury | Presales Consultant | Singapore | Singapore |\n| PB         | Ong       | Director of Sales | Singapore | Singapore |\n| Aaron      | Kang      | Assistant Sales Manager | Singapore | Singapore |\n| Janet      | Liew      | Inside Sales Representative | Singapore | Singapore |\n| Du         | Alex      | Property sales | Singapore | Singapore |\n| Zach       | Lee       | Regional Channel Sales Director-SEA | Singapore | Singapore |\n| Siew       | Tay       | Sales Manager | Singapore | Singapore |\n| Imelda     | Zhang     | Head of Service Sales Siemens | Singapore | Singapore |\n| David      | Tang      | Sales and Marketing | Singapore | Singapore |\n| Nije       | Aw        | Vacation Sales Consultant | Singapore | Singapore |\n| Ashley     | Hansen    | Vice President, Sales & Distribution, Asia Pacific excluding China & South Asia Marriott International | Singapore | Singapore |\n\nThis list includes various roles related to sales, from Sales Executives to Directors of Sales, all based in Singapore. If you need more specific information or further details, feel free to ask!'}

# %%
agent.invoke({"input": "Find sales people working for over a year in Singapore."})
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_query_checker` with `{'query': "SELECT first_name, last_name, job_title, person_city, person_country, duration_in_current_job \nFROM people \nWHERE job_title ILIKE '%Sales%' \nAND person_country = 'Singapore' \nAND years_in_current_job > 1;"}`
# responded: To find salespeople working for over a year in Singapore, I will first query the `people` table to filter for individuals with a job title related to sales and who have been in their current job for more than one year.
#
# Let's construct the query accordingly.
#
# 1. Filter for job titles that include "Sales".
# 2. Filter for people located in Singapore.
# 3. Filter for those who have been in their current job for more than 1 year.
#
# I'll proceed to check the query before executing it.
#
# Here's the query I will use:
#
# ```sql
# SELECT first_name, last_name, job_title, person_city, person_country, duration_in_current_job
# FROM people
# WHERE job_title ILIKE '%Sales%'
# AND person_country = 'Singapore'
# AND years_in_current_job > 1;
# ```
#
# Now, I will check this query for correctness.
#
# ```sql
# SELECT first_name, last_name, job_title, person_city, person_country, duration_in_current_job
# FROM people
# WHERE job_title ILIKE '%Sales%'
# AND person_country = 'Singapore'
# AND duration_in_current_job > 1;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT first_name, last_name, job_title, person_city, person_country, duration_in_current_job \nFROM people \nWHERE job_title ILIKE '%Sales%' \nAND person_country = 'Singapore' \nAND duration_in_current_job > 1;"}`
#
#
# Error: (psycopg2.errors.UndefinedFunction) operator does not exist: text > integer
# LINE 5: AND duration_in_current_job > 1;
#                                     ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.
#
# [SQL: SELECT first_name, last_name, job_title, person_city, person_country, duration_in_current_job
# FROM people
# WHERE job_title ILIKE '%%Sales%%'
# AND person_country = 'Singapore'
# AND duration_in_current_job > 1;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Invoking: `sql_db_schema` with `{'table_names': 'people'}`
# responded: It seems that there was an error because the `duration_in_current_job` column is likely not a numeric type that can be compared directly to an integer. I will need to check the schema of the `people` table to understand the data type of the `duration_in_current_job` column.
#
# Let me retrieve the schema for the `people` table.
#
#
# CREATE TABLE people (
# 	index BIGINT,
# 	first_name TEXT,
# 	middle_name TEXT,
# 	last_name TEXT,
# 	job_title TEXT,
# 	person_city TEXT,
# 	person_state TEXT,
# 	person_country TEXT,
# 	email_pattern TEXT,
# 	homepage_base_url TEXT,
# 	duration_in_current_job TEXT,
# 	duration_in_current_company TEXT,
# 	email_address TEXT,
# 	email_valid BOOLEAN,
# 	full_name TEXT,
# 	years_in_current_job BIGINT
# )
#
# /*
# 3 rows from people table:
# index	first_name	middle_name	last_name	job_title	person_city	person_state	person_country	email_pattern	homepage_base_url	duration_in_current_job	duration_in_current_company	email_address	email_valid	full_name	years_in_current_job
# 0	Cynthia	None	Battini	Indirect Buyer	None	None	France	None	ariane.group	None	None	None	False	Cynthia Battini	0
# 1	Alexander	None	McClure	Public Relations	Austin	TX	US	None	amazon.com	None	None	None	False	Alexander Mcclure	0
# 2	Nadir	None	Shaari	SEO Junior Account Manager	London	None	GB	[first].[last]	artefact.com	None	None	nadir.shaari@artefact.com	True	Nadir Shaari	0
# */
# Invoking: `sql_db_query_checker` with `{'query': "SELECT first_name, last_name, job_title, person_city, person_country, years_in_current_job \nFROM people \nWHERE job_title ILIKE '%Sales%' \nAND person_country = 'Singapore' \nAND years_in_current_job > 1;"}`
# responded: The `duration_in_current_job` column is of type `TEXT`, which means I cannot directly compare it to an integer. Instead, I will need to check if it contains a string that indicates a duration longer than one year.
#
# Since the `years_in_current_job` column is of type `BIGINT`, I will use that column to filter for people who have been in their current job for more than one year.
#
# I will revise the query to use `years_in_current_job` instead of `duration_in_current_job`. Here’s the updated query:
#
# ```sql
# SELECT first_name, last_name, job_title, person_city, person_country, years_in_current_job
# FROM people
# WHERE job_title ILIKE '%Sales%'
# AND person_country = 'Singapore'
# AND years_in_current_job > 1;
# ```
#
# Now, I will check this revised query for correctness.
#
# ```sql
# SELECT first_name, last_name, job_title, person_city, person_country, years_in_current_job
# FROM people
# WHERE job_title ILIKE '%Sales%'
# AND person_country = 'Singapore'
# AND years_in_current_job > 1;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT first_name, last_name, job_title, person_city, person_country, years_in_current_job \nFROM people \nWHERE job_title ILIKE '%Sales%' \nAND person_country = 'Singapore' \nAND years_in_current_job > 1;"}`
#
#
# [('Koh', 'Jing How', 'Enterprise Sales SEA PayPal', None, 'Singapore', 6), ('Patricia', 'A.', 'Sales Manager ASEAN Siemens', 'Singapore', 'Singapore', 9), ('Zhiming', 'Fong', 'Director Strategic Partnerships & Sales, APAC Amadeus', None, 'Singapore', 2), ('Annabel', 'Chang', 'Sales Development Manager (APJ) KnowBe4', None, 'Singapore', 11), ('Audrey', 'Seow', 'Cluster Director of Sales and Marketing, JW Marriott Singapore and The St Regis Singapore Marriott International', None, 'Singapore', 3), ('Anna', 'Chiang', 'Sales Executive Bloomberg Businessweek', None, 'Singapore', 12), ('Vincent', 'Ang', 'Sales Manager Siemens', None, 'Singapore', 8), ('Ericka', 'T.', 'Regional Sales Manager - Indonesia Splunk', None, 'Singapore', 2), ('Gary', 'T.', 'Commercial Sales Executive Amadeus', None, 'Singapore', 6), ('Greta', 'Yap', 'Regional Sales Manager Darktrace', 'Singapore', 'Singapore', 6), ('Satish', 'Khanna', 'Director Sales Siemens Energy - Power & Gas', 'Singapore', 'Singapore', 16), ('Ericka', 'T.', 'Regional Sales Manager - Indonesia Splunk', None, 'Singapore', 2), ('Shabab', 'MK', 'APAC Ecosystem Sales Manager Hewlett Packard Enterprise', None, 'Singapore', 2), ('Shruti', 'More', 'Renewals Sales Specialist (ANZ & INDIA) SUSE', None, 'Singapore', 7), ('Yak', 'Ng', 'Sales Manager Mitsubishi Electric', None, 'Singapore', 4), ('Mary', 'L.', 'Director Channel Sales (Asia) BlackBerry', None, 'Singapore', 5), ('Angela', 'YAP', 'Sales Representative Hewlett-Packard', None, 'Singapore', 9), ('Ashley', 'Hansen', 'Vice President, Sales & Distribution, Asia Pacific excluding China & South Asia Marriott International', 'Singapore', 'Singapore', 10), ('Ng', 'Wen', 'Cluster Sales Executive Marriott International', 'Singapore', 'Singapore', 4), ('Melissa', 'Ong', 'Global Account Director, Luxury Sales Marriott International', None, 'Singapore', 4), ('Imelda', 'Zhang', 'Head of Service Sales Siemens', 'Singapore', 'Singapore', 2), ('Jack', 'Yeong', 'Sales Development SolarWinds', None, 'Singapore', 6), ('Henry', 'Ho', 'Country Sales Manager Emerson', None, 'Singapore', 4), ('Sonia', 'Chong', 'Senior Sales Enablement Specialist, Growth Markets PayPal', None, 'Singapore', 3), ('Shankarapandian', 'Ravi', 'Sales Specialist Hewlett Packard Enterprise', None, 'Singapore', 9), ('Chiang', 'Tang', 'Sales Director Amadeus', None, 'Singapore', 16), ('Ivan', 'Lee', 'Sales Director Fujitsu Singapore', 'Singapore', 'Singapore', 11), ('Pooja', 'S.', 'Head Enterprise Sales, South East Asia PayPal', None, 'Singapore', 6), ('Kenneth', 'Ang', 'Sales Director - iGaming Cloudflare', None, 'Singapore', 8), ('Francesco', 'Saraceno', 'Senior Sales Manager - Air-x, Metasearch & Digital Players Amadeus', None, 'Singapore', 9), ('Amanda', 'Lau', 'Senior Sales Development Representative Okta', None, 'Singapore', 8), ('Angela', 'YAP', 'Sales Representative Hewlett-Packard', None, 'Singapore', 9), ('Kenneth', 'Yeap', 'Sales and Bids Director Siemens Mobility Pte Ltd', None, 'Singapore', 4), ('Melvin', 'Phua', 'Tech Sales Specialist Hewlett Packard Enterprise', 'Singapore', 'Singapore', 3), ('Calvin', 'Ng', 'Senior Sales Engineer Splunk', None, 'Singapore', 3), ('Renee', 'Looi', 'Event Sales Manager Marriott International', None, 'Singapore', 11), ('Haitao', 'Xu', 'Regional Sales Manager (China) Cloudflare, Inc.', None, 'Singapore', 5), ('Yu', 'Chew', 'Sales Merchandiser, Global Sales, Singapore Marriott International', None, 'Singapore', 4), ('Amanda', 'Lau', 'Senior Sales Development Representative Okta', None, 'Singapore', 8), ('Jenny', 'Tan', 'Enterprise Sales, Public Sector Hewlett Packard Enterprise', None, 'Singapore', 4), ('Audrey', 'Seow', 'Cluster Director of Sales and Marketing, JW Marriott Singapore and The St Regis Singapore Marriott International', None, 'Singapore', 3), ('Ashley', 'Hansen', 'Vice President, Sales & Distribution, Asia Pacific excluding China & South Asia Marriott International', 'Singapore', 'Singapore', 10), ('weijie', 'LIM', 'APAC Channel Sa ...
#
# | First Name | Last Name | Job Title                                                                 | City      | Country   | Years in Current Job |
# |------------|-----------|---------------------------------------------------------------------------|-----------|-----------|----------------------|
# | Koh        | Jing How  | Enterprise Sales SEA PayPal                                               | None      | Singapore | 6                    |
# | Patricia   | A.        | Sales Manager ASEAN Siemens                                               | Singapore | Singapore | 9                    |
# | Zhiming    | Fong      | Director Strategic Partnerships & Sales, APAC Amadeus                    | None      | Singapore | 2                    |
# | Annabel    | Chang     | Sales Development Manager (APJ) KnowBe4                                   | None      | Singapore | 11                   |
# | Audrey     | Seow      | Cluster Director of Sales and Marketing, JW Marriott Singapore            | None      | Singapore | 3                    |
# | Anna       | Chiang    | Sales Executive Bloomberg Businessweek                                     | None      | Singapore | 12                   |
# | Vincent    | Ang       | Sales Manager Siemens                                                     | None      | Singapore | 8                    |
# | Ericka     | T.        | Regional Sales Manager - Indonesia Splunk                                  | None      | Singapore | 2                    |
# | Gary       | T.        | Commercial Sales Executive Amadeus                                        | None      | Singapore | 6                    |
# | Greta      | Yap       | Regional Sales Manager Darktrace                                          | Singapore | Singapore | 6                    |
# | Satish     | Khanna    | Director Sales Siemens Energy - Power & Gas                                | Singapore | Singapore | 16                   |
# | Shabab     | MK        | APAC Ecosystem Sales Manager Hewlett Packard Enterprise                   | None      | Singapore | 2                    |
# | Shruti     | More      | Renewals Sales Specialist (ANZ & INDIA) SUSE                              | None      | Singapore | 7                    |
# | Yak        | Ng        | Sales Manager Mitsubishi Electric                                          | None      | Singapore | 4                    |
# | Mary       | L.        | Director Channel Sales (Asia) BlackBerry                                   | None      | Singapore | 5                    |
# | Angela     | YAP       | Sales Representative Hewlett-Packard                                       | None      | Singapore | 9                    |
# | Ashley     | Hansen    | Vice President, Sales & Distribution, Asia Pacific excluding China & South Asia Marriott International | Singapore | Singapore | 10                   |
# | Ng         | Wen       | Cluster Sales Executive Marriott International                              | Singapore | Singapore | 4                    |
# | Melissa    | Ong       | Global Account Director, Luxury Sales Marriott International               | None      | Singapore | 4                    |
# | Imelda     | Zhang     | Head of Service Sales Siemens                                              | Singapore | Singapore | 2                    |
# | Jack       | Yeong     | Sales Development SolarWinds                                              | None      | Singapore | 6                    |
# | Henry      | Ho        | Country Sales Manager Emerson                                              | None      | Singapore | 4                    |
# | Sonia      | Chong     | Senior Sales Enablement Specialist, Growth Markets PayPal                 | None      | Singapore | 3                    |
# | Shankarapandian | Ravi | Sales Specialist Hewlett Packard Enterprise                                 | None      | Singapore | 9                    |
# | Chiang     | Tang      | Sales Director Amadeus                                                    | None      | Singapore | 16                   |
# | Ivan       | Lee       | Sales Director Fujitsu Singapore                                           | Singapore | Singapore | 11                   |
# | Pooja      | S.        | Head Enterprise Sales, South East Asia PayPal                             | None      | Singapore | 6                    |
# | Kenneth    | Ang       | Sales Director - iGaming Cloudflare                                        | None      | Singapore | 8                    |
# | Francesco   | Saraceno | Senior Sales Manager - Air-x, Metasearch & Digital Players Amadeus       | None      | Singapore | 9                    |
# | Amanda     | Lau       | Senior Sales Development Representative Okta                                | None      | Singapore | 8                    |
# | Kenneth    | Yeap      | Sales and Bids Director Siemens Mobility Pte Ltd                          | None      | Singapore | 4                    |
# | Melvin     | Phua      | Tech Sales Specialist Hewlett Packard Enterprise                           | Singapore | Singapore | 3                    |
# | Calvin     | Ng        | Senior Sales Engineer Splunk                                              | None      | Singapore | 3                    |
# | Renee      | Looi      | Event Sales Manager Marriott International                                 | None      | Singapore | 11                   |
# | Haitao     | Xu        | Regional Sales Manager (China) Cloudflare, Inc.                          | None      | Singapore | 5                    |
# | Yu         | Chew      | Sales Merchandiser, Global Sales, Singapore Marriott International        | None      | Singapore | 4                    |
# | Jenny      | Tan       | Enterprise Sales, Public Sector Hewlett Packard Enterprise                | None      | Singapore | 4                    |
# | Audrey     | Seow      | Cluster Director of Sales and Marketing, JW Marriott Singapore            | None      | Singapore | 3                    |
# | Ashley     | Hansen    | Vice President, Sales & Distribution, Asia Pacific excluding China & South Asia Marriott International | Singapore | Singapore | 10                   |
# | weijie     | LIM       | APAC Channel Sales Hewlett Packard Enterprise                              | None      | Singapore | 2                    |
#
# If you need any further information or specific details, feel free to ask!
#
# > Finished chain.
# {'input': 'Find sales people working for over a year in Singapore.',
#  'output': 'Here are the salespeople working in Singapore for over a year:\n\n| First Name | Last Name | Job Title                                                                 | City      | Country   | Years in Current Job |\n|------------|-----------|---------------------------------------------------------------------------|-----------|-----------|----------------------|\n| Koh        | Jing How  | Enterprise Sales SEA PayPal                                               | None      | Singapore | 6                    |\n| Patricia   | A.        | Sales Manager ASEAN Siemens                                               | Singapore | Singapore | 9                    |\n| Zhiming    | Fong      | Director Strategic Partnerships & Sales, APAC Amadeus                    | None      | Singapore | 2                    |\n| Annabel    | Chang     | Sales Development Manager (APJ) KnowBe4                                   | None      | Singapore | 11                   |\n| Audrey     | Seow      | Cluster Director of Sales and Marketing, JW Marriott Singapore            | None      | Singapore | 3                    |\n| Anna       | Chiang    | Sales Executive Bloomberg Businessweek                                     | None      | Singapore | 12                   |\n| Vincent    | Ang       | Sales Manager Siemens                                                     | None      | Singapore | 8                    |\n| Ericka     | T.        | Regional Sales Manager - Indonesia Splunk                                  | None      | Singapore | 2                    |\n| Gary       | T.        | Commercial Sales Executive Amadeus                                        | None      | Singapore | 6                    |\n| Greta      | Yap       | Regional Sales Manager Darktrace                                          | Singapore | Singapore | 6                    |\n| Satish     | Khanna    | Director Sales Siemens Energy - Power & Gas                                | Singapore | Singapore | 16                   |\n| Shabab     | MK        | APAC Ecosystem Sales Manager Hewlett Packard Enterprise                   | None      | Singapore | 2                    |\n| Shruti     | More      | Renewals Sales Specialist (ANZ & INDIA) SUSE                              | None      | Singapore | 7                    |\n| Yak        | Ng        | Sales Manager Mitsubishi Electric                                          | None      | Singapore | 4                    |\n| Mary       | L.        | Director Channel Sales (Asia) BlackBerry                                   | None      | Singapore | 5                    |\n| Angela     | YAP       | Sales Representative Hewlett-Packard                                       | None      | Singapore | 9                    |\n| Ashley     | Hansen    | Vice President, Sales & Distribution, Asia Pacific excluding China & South Asia Marriott International | Singapore | Singapore | 10                   |\n| Ng         | Wen       | Cluster Sales Executive Marriott International                              | Singapore | Singapore | 4                    |\n| Melissa    | Ong       | Global Account Director, Luxury Sales Marriott International               | None      | Singapore | 4                    |\n| Imelda     | Zhang     | Head of Service Sales Siemens                                              | Singapore | Singapore | 2                    |\n| Jack       | Yeong     | Sales Development SolarWinds                                              | None      | Singapore | 6                    |\n| Henry      | Ho        | Country Sales Manager Emerson                                              | None      | Singapore | 4                    |\n| Sonia      | Chong     | Senior Sales Enablement Specialist, Growth Markets PayPal                 | None      | Singapore | 3                    |\n| Shankarapandian | Ravi | Sales Specialist Hewlett Packard Enterprise                                 | Non ...

# %%
agent.invoke({"input": "Find the people working the longest in their current company."})
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_query_checker` with `{'query': 'SELECT first_name, last_name, duration_in_current_company FROM people ORDER BY duration_in_current_company DESC LIMIT 5;'}`
#
#
# ```sql
# SELECT first_name, last_name, duration_in_current_company FROM people ORDER BY duration_in_current_company DESC LIMIT 5;
# ```
# Invoking: `sql_db_query` with `{'query': 'SELECT first_name, last_name, duration_in_current_company FROM people ORDER BY duration_in_current_company DESC LIMIT 5;'}`
#
#
# [('Alexander', 'McClure', None), ('Nadir', 'Shaari', None), ('Daniela', 'Bonvino', None), ('Nikita', 'Kushwa', None), ('Cynthia', 'Battini', None)]It appears that the data for the duration of employment in the current company is not available (all values are `None`). Therefore, I cannot provide the names of people working the longest in their current company based on the available information.
#
# If you have any other questions or need information on a different topic, feel free to ask!
#
# > Finished chain.
# {'input': 'Find the people working the longest in their current company.',
#  'output': 'It appears that the data for the duration of employment in the current company is not available (all values are `None`). Therefore, I cannot provide the names of people working the longest in their current company based on the available information. \n\nIf you have any other questions or need information on a different topic, feel free to ask!'}

# %%
agent.invoke({"input": "Find me the events happening in the next 6 months."})
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_query_checker` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date BETWEEN CURRENT_DATE AND CURRENT_DATE + INTERVAL '6 months' ORDER BY event_start_date;"}`
#
#
# ```sql
# SELECT event_name, event_start_date, event_end_date, event_venue, event_country
# FROM event
# WHERE event_start_date BETWEEN CURRENT_DATE AND CURRENT_DATE + INTERVAL '6 months'
# ORDER BY event_start_date;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date BETWEEN CURRENT_DATE AND CURRENT_DATE + INTERVAL '6 months' ORDER BY event_start_date;"}`
#
#
# Error: (psycopg2.errors.UndefinedFunction) operator does not exist: text >= date
# LINE 1: ..., event_country FROM event WHERE event_start_date BETWEEN CU...
#                                                              ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.
#
# [SQL: SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date BETWEEN CURRENT_DATE AND CURRENT_DATE + INTERVAL '6 months' ORDER BY event_start_date;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Invoking: `sql_db_query_checker` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date::date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '6 months')::date ORDER BY event_start_date;"}`
#
#
# ```sql
# SELECT event_name, event_start_date, event_end_date, event_venue, event_country
# FROM event
# WHERE event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '6 months')
# ORDER BY event_start_date;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date::date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '6 months')::date ORDER BY event_start_date;"}`
#
#
# [('SG Pet Festival 2024', '2024-08-02', '2024-08-04', 'Marina Bay Sands Singapore Convention Centre, Level 1, Hall A, B & C', None), ("MBA and Master's Fair in Singapore", '2024-08-17', '2024-08-17', 'Carlton Hotel Singapore', None), ('The Business Show Asia', '2024-08-28', '2024-08-29', 'Sands Expo & Convention Centre', None), ('ISPE Singapore Conference & Exhibition 2024', '2024-08-28', '2024-08-30', 'Suntec Singapore', None), ('Yummy Food Expo 2024', '2024-08-29', '2024-09-01', 'Singapore Expo', None), ('ISS World Asia', '2024-09-03', '2024-09-05', None, None), ('Seafood Expo Asia', '2024-09-04', '2024-09-06', 'Sands Expo and Convention Centre', None), ('BEX Asia', '2024-09-04', '2024-09-06', 'Marina Bay Sands', None), ('MEDICAL FAIR ASIA', '2024-09-11', '2024-09-13', 'Marina Bay Sands', None), ('CeMAT Southeast Asia', '2024-09-12', '2024-09-14', 'Singapore EXPO', 'Singapore'), ('CeMAT Southeast Asia', '2024-09-12', '2024-09-14', 'Singapore EXPO', None), ('CeMAT Southeast Asia', '2024-09-17', '2024-09-19', 'Singapore EXPO', 'Singapore'), ('CeMAT Southeast Asia', '2024-09-17', '2024-09-19', 'Singapore EXPO', 'Singapore'), ('CeMAT Southeast Asia', '2024-09-17', '2024-09-19', 'Singapore EXPO', None), ('CeMAT Southeast Asia', '2024-09-17', '2024-09-19', 'Singapore EXPO', 'Singapore'), ('CeMAT Southeast Asia', '2024-09-17', '2024-09-19', 'Singapore EXPO', 'Singapore'), ('DigiMarCon Asia Pacific 2024-Digital Marketing Conference & Exhibition', '2024-09-19', '2024-09-20', 'Marina Bay Sands Expo and Convention Centre', 'Australia'), ('International Conference and Exhibition on Pharmaceutics and Drug Delivery Systems', '2024-09-23', '2024-09-24', 'Singapore', None), ('Submarine Networks World 2024', '2024-09-25', '2024-09-26', 'Suntec Convention Centre', None), ('FIND-Design Fair Asia', '2024-09-26', '2024-09-28', 'Level B2, Marina Bay Sands', None), ('Cyber Security World Asia', '2024-10-09', '2024-10-10', 'Marina Bay Sands', None), ('Big Data & AI World Asia', '2024-10-09', '2024-10-10', 'Marina Bay Sands Expo & Convention Centre, Singapore', None), ('Cloud Expo Asia Singapore 2024', '2024-10-09', '2024-10-10', 'Marina Bay Sands', None), ('eCommerce Expo Asia', '2024-10-09', '2024-10-10', 'Marina Bay Sands Expo & Convention Centre', None), ('Industrial Transformation ASIA-PACIFIC 2024', '2024-10-14', '2024-10-16', 'Singapore EXPO', 'Singapore'), ('Accounting & Business Show Asia 2024', '2024-10-16', '2024-10-17', 'Sands Expo & Convention Centre, Singapore', None), ("2nd Edition of Global Conference on Gynecology & Women's Health", '2024-10-17', '2024-10-19', 'Best Western Plus Hotel & Conference Center', 'Maryland, USA'), ('Worldchefs Congress & Expo 2024', '2024-10-20', '2024-10-25', 'Singapore', None), ('ITB Asia', '2024-10-23', '2024-10-25', 'Marina Bay Sands', 'Singapore'), ('Asian Refining Technology Conference', '2024-10-23', '2024-10-24', 'Sands Expo & Convention Centre, Singapore', None), ('Asian Downstream Summit', '2024-10-23', '2024-10-24', 'Sands Expo & Convention Centre, Singapore', None), ('Food Japan 2024', '2024-10-24', '2024-10-26', 'Suntec Singapore', None), ('EDUtech_Asia 2024', '2024-11-05', '2024-11-07', 'Sands Expo & Convention Centre, Singapore', None), ('LTA-UITP Singapore International Transport Congress & Exhibition 2024', '2024-11-06', '2024-11-08', 'Suntec Singapore Exhibition and Convention Centre', None), ('Architecture & Building Services (ABS) 2024', '2024-11-13', '2024-11-15', 'Marina Bay Sands Expo & Convention Centre Singapore', None), ('UTECH Southeast Asia', '2024-11-13', '2024-11-14', 'Marina Bay Sands', None), ('The Big Furniture Fair 2024', '2024-11-15', '2024-11-17', 'Singapore EXPO', 'Singapore'), ('OSEA 2024', '2024-11-19', '2024-11-21', 'Marina Bay Sands', None), ('Process Innovation Asia-Pacific', '2024-11-19', '2024-11-21', 'Canton Fair Complex, Guangzhou', None), ('11th Middle East Insurance Industry Awards 2024', '2024-11-21', '2024-11-21', 'Dubai', 'United Arab Emirates'), ('11th Mi ...
#
# | Event Name                                               | Start Date  | End Date    | Venue                                                        | Country               |
# |---------------------------------------------------------|-------------|-------------|--------------------------------------------------------------|-----------------------|
# | SG Pet Festival 2024                                    | 2024-08-02  | 2024-08-04  | Marina Bay Sands Singapore Convention Centre, Level 1, Hall A, B & C | None                  |
# | MBA and Master's Fair in Singapore                      | 2024-08-17  | 2024-08-17  | Carlton Hotel Singapore                                      | None                  |
# | The Business Show Asia                                   | 2024-08-28  | 2024-08-29  | Sands Expo & Convention Centre                               | None                  |
# | ISPE Singapore Conference & Exhibition 2024             | 2024-08-28  | 2024-08-30  | Suntec Singapore                                            | None                  |
# | Yummy Food Expo 2024                                    | 2024-08-29  | 2024-09-01  | Singapore Expo                                              | None                  |
# | ISS World Asia                                          | 2024-09-03  | 2024-09-05  | None                                                         | None                  |
# | Seafood Expo Asia                                       | 2024-09-04  | 2024-09-06  | Sands Expo and Convention Centre                             | None                  |
# | BEX Asia                                                | 2024-09-04  | 2024-09-06  | Marina Bay Sands                                            | None                  |
# | MEDICAL FAIR ASIA                                       | 2024-09-11  | 2024-09-13  | Marina Bay Sands                                            | None                  |
# | CeMAT Southeast Asia                                     | 2024-09-12  | 2024-09-14  | Singapore EXPO                                             | Singapore             |
# | DigiMarCon Asia Pacific 2024-Digital Marketing Conference & Exhibition | 2024-09-19  | 2024-09-20  | Marina Bay Sands Expo and Convention Centre                 | Australia             |
# | International Conference and Exhibition on Pharmaceutics and Drug Delivery Systems | 2024-09-23  | 2024-09-24  | Singapore                                                   | None                  |
# | Submarine Networks World 2024                            | 2024-09-25  | 2024-09-26  | Suntec Convention Centre                                     | None                  |
# | Cyber Security World Asia                                 | 2024-10-09  | 2024-10-10  | Marina Bay Sands                                            | None                  |
# | Big Data & AI World Asia                                 | 2024-10-09  | 2024-10-10  | Marina Bay Sands Expo & Convention Centre, Singapore        | None                  |
# | Industrial Transformation ASIA-PACIFIC 2024             | 2024-10-14  | 2024-10-16  | Singapore EXPO                                             | Singapore             |
# | Worldchefs Congress & Expo 2024                         | 2024-10-20  | 2024-10-25  | Singapore                                                   | None                  |
# | EDUtech_Asia 2024                                       | 2024-11-05  | 2024-11-07  | Sands Expo & Convention Centre, Singapore                   | None                  |
# | Home Inspirations 2024                                   | 2024-12-05  | 2024-12-07  | Singapore EXPO                                             | None                  |
#
# If you need more details about any specific event, feel free to ask!
#
# > Finished chain.
# {'input': 'Find me the events happening in the next 6 months.',
#  'output': "Here are the events happening in the next 6 months:\n\n| Event Name                                               | Start Date  | End Date    | Venue                                                        | Country               |\n|---------------------------------------------------------|-------------|-------------|--------------------------------------------------------------|-----------------------|\n| SG Pet Festival 2024                                    | 2024-08-02  | 2024-08-04  | Marina Bay Sands Singapore Convention Centre, Level 1, Hall A, B & C | None                  |\n| MBA and Master's Fair in Singapore                      | 2024-08-17  | 2024-08-17  | Carlton Hotel Singapore                                      | None                  |\n| The Business Show Asia                                   | 2024-08-28  | 2024-08-29  | Sands Expo & Convention Centre                               | None                  |\n| ISPE Singapore Conference & Exhibition 2024             | 2024-08-28  | 2024-08-30  | Suntec Singapore                                            | None                  |\n| Yummy Food Expo 2024                                    | 2024-08-29  | 2024-09-01  | Singapore Expo                                              | None                  |\n| ISS World Asia                                          | 2024-09-03  | 2024-09-05  | None                                                         | None                  |\n| Seafood Expo Asia                                       | 2024-09-04  | 2024-09-06  | Sands Expo and Convention Centre                             | None                  |\n| BEX Asia                                                | 2024-09-04  | 2024-09-06  | Marina Bay Sands                                            | None                  |\n| MEDICAL FAIR ASIA                                       | 2024-09-11  | 2024-09-13  | Marina Bay Sands                                            | None                  |\n| CeMAT Southeast Asia                                     | 2024-09-12  | 2024-09-14  | Singapore EXPO                                             | Singapore             |\n| DigiMarCon Asia Pacific 2024-Digital Marketing Conference & Exhibition | 2024-09-19  | 2024-09-20  | Marina Bay Sands Expo and Convention Centre                 | Australia             |\n| International Conference and Exhibition on Pharmaceutics and Drug Delivery Systems | 2024-09-23  | 2024-09-24  | Singapore                                                   | None                  |\n| Submarine Networks World 2024                            | 2024-09-25  | 2024-09-26  | Suntec Convention Centre                                     | None                  |\n| Cyber Security World Asia                                 | 2024-10-09  | 2024-10-10  | Marina Bay Sands                                            | None                  |\n| Big Data & AI World Asia                                 | 2024-10-09  | 2024-10-10  | Marina Bay Sands Expo & Convention Centre, Singapore        | None                  |\n| Industrial Transformation ASIA-PACIFIC 2024             | 2024-10-14  | 2024-10-16  | Singapore EXPO                                             | Singapore             |\n| Worldchefs Congress & Expo 2024                         | 2024-10-20  | 2024-10-25  | Singapore                                                   | None                  |\n| EDUtech_Asia 2024                                       | 2024-11-05  | 2024-11-07  | Sands Expo & Convention Centre, Singapore                   | None                  |\n| Home Inspirations 2024                                   | 2024-12-05  | 2024-12-07  | Singapore EXPO                                             | None                  |\n\nIf you need more details about any specific event, feel free to ask!"}

# %%
agent.invoke({"input": "Find me the events happening in the next 12 months."})
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_query_checker` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date BETWEEN CURRENT_DATE AND CURRENT_DATE + INTERVAL '1 year' ORDER BY event_start_date;"}`
#
#
# ```sql
# SELECT event_name, event_start_date, event_end_date, event_venue, event_country
# FROM event
# WHERE event_start_date BETWEEN CURRENT_DATE AND CURRENT_DATE + INTERVAL '1 year'
# ORDER BY event_start_date;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date BETWEEN CURRENT_DATE AND CURRENT_DATE + INTERVAL '1 year' ORDER BY event_start_date;"}`
#
#
# Error: (psycopg2.errors.UndefinedFunction) operator does not exist: text >= date
# LINE 1: ..., event_country FROM event WHERE event_start_date BETWEEN CU...
#                                                              ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.
#
# [SQL: SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date BETWEEN CURRENT_DATE AND CURRENT_DATE + INTERVAL '1 year' ORDER BY event_start_date;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Invoking: `sql_db_query_checker` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date::date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '1 year') ORDER BY event_start_date;"}`
#
#
# ```sql
# SELECT event_name, event_start_date, event_end_date, event_venue, event_country
# FROM event
# WHERE event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '1 year')
# ORDER BY event_start_date;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '1 year') ORDER BY event_start_date;"}`
#
#
# Error: (psycopg2.errors.UndefinedFunction) operator does not exist: text >= date
# LINE 1: ..., event_country FROM event WHERE event_start_date BETWEEN CU...
#                                                              ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.
#
# [SQL: SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '1 year') ORDER BY event_start_date;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Invoking: `sql_db_query_checker` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date::date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '1 year')::date ORDER BY event_start_date;"}`
#
#
# ```sql
# SELECT event_name, event_start_date, event_end_date, event_venue, event_country
# FROM event
# WHERE event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '1 year')
# ORDER BY event_start_date;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '1 year')::date ORDER BY event_start_date;"}`
#
#
# Error: (psycopg2.errors.UndefinedFunction) operator does not exist: text >= date
# LINE 1: ..., event_country FROM event WHERE event_start_date BETWEEN CU...
#                                                              ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.
#
# [SQL: SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '1 year')::date ORDER BY event_start_date;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Invoking: `sql_db_query_checker` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date::date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '1 year')::date ORDER BY event_start_date;"}`
#
#
# ```sql
# SELECT event_name, event_start_date, event_end_date, event_venue, event_country
# FROM event
# WHERE event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '1 year')
# ORDER BY event_start_date;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '1 year') ORDER BY event_start_date;"}`
#
#
# Error: (psycopg2.errors.UndefinedFunction) operator does not exist: text >= date
# LINE 1: ..., event_country FROM event WHERE event_start_date BETWEEN CU...
#                                                              ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.
#
# [SQL: SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '1 year') ORDER BY event_start_date;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Invoking: `sql_db_query_checker` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date::timestamp BETWEEN CURRENT_TIMESTAMP AND (CURRENT_TIMESTAMP + INTERVAL '1 year') ORDER BY event_start_date;"}`
#
#
# ```sql
# SELECT event_name, event_start_date, event_end_date, event_venue, event_country
# FROM event
# WHERE event_start_date BETWEEN CURRENT_TIMESTAMP AND (CURRENT_TIMESTAMP + INTERVAL '1 year')
# ORDER BY event_start_date;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT event_name, event_start_date, event_end_date, event_venue, event_country FROM event WHERE event_start_date::timestamp BETWEEN CURRENT_TIMESTAMP AND (CURRENT_TIMESTAMP + INTERVAL '1 year') ORDER BY event_start_date;"}`
#
#
# [('SG Pet Festival 2024', '2024-08-02', '2024-08-04', 'Marina Bay Sands Singapore Convention Centre, Level 1, Hall A, B & C', None), ("MBA and Master's Fair in Singapore", '2024-08-17', '2024-08-17', 'Carlton Hotel Singapore', None), ('ISPE Singapore Conference & Exhibition 2024', '2024-08-28', '2024-08-30', 'Suntec Singapore', None), ('The Business Show Asia', '2024-08-28', '2024-08-29', 'Sands Expo & Convention Centre', None), ('Yummy Food Expo 2024', '2024-08-29', '2024-09-01', 'Singapore Expo', None), ('ISS World Asia', '2024-09-03', '2024-09-05', None, None), ('Seafood Expo Asia', '2024-09-04', '2024-09-06', 'Sands Expo and Convention Centre', None), ('BEX Asia', '2024-09-04', '2024-09-06', 'Marina Bay Sands', None), ('MEDICAL FAIR ASIA', '2024-09-11', '2024-09-13', 'Marina Bay Sands', None), ('CeMAT Southeast Asia', '2024-09-12', '2024-09-14', 'Singapore EXPO', None), ('CeMAT Southeast Asia', '2024-09-12', '2024-09-14', 'Singapore EXPO', 'Singapore'), ('CeMAT Southeast Asia', '2024-09-17', '2024-09-19', 'Singapore EXPO', 'Singapore'), ('CeMAT Southeast Asia', '2024-09-17', '2024-09-19', 'Singapore EXPO', 'Singapore'), ('CeMAT Southeast Asia', '2024-09-17', '2024-09-19', 'Singapore EXPO', 'Singapore'), ('CeMAT Southeast Asia', '2024-09-17', '2024-09-19', 'Singapore EXPO', 'Singapore'), ('CeMAT Southeast Asia', '2024-09-17', '2024-09-19', 'Singapore EXPO', None), ('DigiMarCon Asia Pacific 2024-Digital Marketing Conference & Exhibition', '2024-09-19', '2024-09-20', 'Marina Bay Sands Expo and Convention Centre', 'Australia'), ('International Conference and Exhibition on Pharmaceutics and Drug Delivery Systems', '2024-09-23', '2024-09-24', 'Singapore', None), ('Submarine Networks World 2024', '2024-09-25', '2024-09-26', 'Suntec Convention Centre', None), ('FIND-Design Fair Asia', '2024-09-26', '2024-09-28', 'Level B2, Marina Bay Sands', None), ('Cyber Security World Asia', '2024-10-09', '2024-10-10', 'Marina Bay Sands', None), ('eCommerce Expo Asia', '2024-10-09', '2024-10-10', 'Marina Bay Sands Expo & Convention Centre', None), ('Big Data & AI World Asia', '2024-10-09', '2024-10-10', 'Marina Bay Sands Expo & Convention Centre, Singapore', None), ('Cloud Expo Asia Singapore 2024', '2024-10-09', '2024-10-10', 'Marina Bay Sands', None), ('Industrial Transformation ASIA-PACIFIC 2024', '2024-10-14', '2024-10-16', 'Singapore EXPO', 'Singapore'), ('Accounting & Business Show Asia 2024', '2024-10-16', '2024-10-17', 'Sands Expo & Convention Centre, Singapore', None), ("2nd Edition of Global Conference on Gynecology & Women's Health", '2024-10-17', '2024-10-19', 'Best Western Plus Hotel & Conference Center', 'Maryland, USA'), ('Worldchefs Congress & Expo 2024', '2024-10-20', '2024-10-25', 'Singapore', None), ('ITB Asia', '2024-10-23', '2024-10-25', 'Marina Bay Sands', 'Singapore'), ('Asian Refining Technology Conference', '2024-10-23', '2024-10-24', 'Sands Expo & Convention Centre, Singapore', None), ('Asian Downstream Summit', '2024-10-23', '2024-10-24', 'Sands Expo & Convention Centre, Singapore', None), ('Food Japan 2024', '2024-10-24', '2024-10-26', 'Suntec Singapore', None), ('EDUtech_Asia 2024', '2024-11-05', '2024-11-07', 'Sands Expo & Convention Centre, Singapore', None), ('LTA-UITP Singapore International Transport Congress & Exhibition 2024', '2024-11-06', '2024-11-08', 'Suntec Singapore Exhibition and Convention Centre', None), ('UTECH Southeast Asia', '2024-11-13', '2024-11-14', 'Marina Bay Sands', None), ('Architecture & Building Services (ABS) 2024', '2024-11-13', '2024-11-15', 'Marina Bay Sands Expo & Convention Centre Singapore', None), ('The Big Furniture Fair 2024', '2024-11-15', '2024-11-17', 'Singapore EXPO', 'Singapore'), ('OSEA 2024', '2024-11-19', '2024-11-21', 'Marina Bay Sands', None), ('Process Innovation Asia-Pacific', '2024-11-19', '2024-11-21', 'Canton Fair Complex, Guangzhou', None), ('11th Middle East Insurance Industry Awards 2024', '2024-11-21', '2024-11-21', 'Dubai', 'United Arab Emirates'), ('11th Mi ...
#
# | Event Name                                               | Start Date  | End Date    | Venue                                                        | Country               |
# |---------------------------------------------------------|-------------|-------------|--------------------------------------------------------------|-----------------------|
# | SG Pet Festival 2024                                    | 2024-08-02  | 2024-08-04  | Marina Bay Sands Singapore Convention Centre, Level 1, Hall A, B & C | None                  |
# | MBA and Master's Fair in Singapore                      | 2024-08-17  | 2024-08-17  | Carlton Hotel Singapore                                      | None                  |
# | ISPE Singapore Conference & Exhibition 2024             | 2024-08-28  | 2024-08-30  | Suntec Singapore                                            | None                  |
# | The Business Show Asia                                   | 2024-08-28  | 2024-08-29  | Sands Expo & Convention Centre                               | None                  |
# | Yummy Food Expo 2024                                    | 2024-08-29  | 2024-09-01  | Singapore Expo                                              | None                  |
# | ISS World Asia                                          | 2024-09-03  | 2024-09-05  | None                                                         | None                  |
# | Seafood Expo Asia                                       | 2024-09-04  | 2024-09-06  | Sands Expo and Convention Centre                             | None                  |
# | BEX Asia                                                | 2024-09-04  | 2024-09-06  | Marina Bay Sands                                            | None                  |
# | MEDICAL FAIR ASIA                                       | 2024-09-11  | 2024-09-13  | Marina Bay Sands                                            | None                  |
# | CeMAT Southeast Asia                                    | 2024-09-12  | 2024-09-14  | Singapore EXPO                                             | Singapore             |
# | DigiMarCon Asia Pacific 2024-Digital Marketing Conference & Exhibition | 2024-09-19  | 2024-09-20  | Marina Bay Sands Expo and Convention Centre                 | Australia             |
# | International Conference and Exhibition on Pharmaceutics and Drug Delivery Systems | 2024-09-23  | 2024-09-24  | Singapore                                                   | None                  |
# | Submarine Networks World 2024                            | 2024-09-25  | 2024-09-26  | Suntec Convention Centre                                     | None                  |
# | Cyber Security World Asia                                | 2024-10-09  | 2024-10-10  | Marina Bay Sands                                            | None                  |
# | eCommerce Expo Asia                                     | 2024-10-09  | 2024-10-10  | Marina Bay Sands Expo & Convention Centre                   | None                  |
# | Big Data & AI World Asia                                 | 2024-10-09  | 2024-10-10  | Marina Bay Sands Expo & Convention Centre                   | None                  |
# | Cloud Expo Asia Singapore 2024                          | 2024-10-09  | 2024-10-10  | Marina Bay Sands                                            | None                  |
# | Industrial Transformation ASIA-PACIFIC 2024            | 2024-10-14  | 2024-10-16  | Singapore EXPO                                             | Singapore             |
# | Accounting & Business Show Asia 2024                    | 2024-10-16  | 2024-10-17  | Sands Expo & Convention Centre, Singapore                   | None                  |
# | Worldchefs Congress & Expo 2024                         | 2024-10-20  | 2024-10-25  | Singapore                                                   | None                  |
# | ITB Asia                                                | 2024-10-23  | 2024-10-25  | Marina Bay Sands                                            | Singapore             |
# | Asian Refining Technology Conference                     | 2024-10-23  | 2024-10-24  | Sands Expo & Convention Centre                               | None                  |
# | Food Japan 2024                                         | 2024-10-24  | 2024-10-26  | Suntec Singapore                                            | None                  |
# | EDUtech_Asia 2024                                       | 2024-11-05  | 2024-11-07  | Sands Expo & Convention Centre, Singapore                   | None                  |
# | LTA-UITP Singapore International Transport Congress & Exhibition 2024 | 2024-11-06  | 2024-11-08  | Suntec Singapore Exhibition and Convention Centre           | None                  |
# | OSEA 2024                                               | 2024-11-19  | 2024-11-21  | Marina Bay Sands                                            | None                  |
# | Home Inspirations 2024                                  | 2024-12-05  | 2024-12-07  | Singapore EXPO                                             | None                  |
# | ART SG                                                 | 2025-01-17  | 2025-01-19  | Marina Bay Sands                                            | None                  |
# | Cyber Security Summit Singapore                          | 2025-02-01  | 2025-02-01  | Singapore                                                   | Singapore             |
# | BeautyAsia                                              | 2025-02-17  | 2025-02-19  | Marina Bay Sands                                            | None                  |
# | AHICE South East Asia                                   | 2025-02-25  | 2025-02-26  | Pan Pacific Singapore                                       | None                  |
# | Commodity Trading Week APAC                              | 2025-02-25  | 2025-02-26  | Marina Bay Sands                                            | None                  |
#
# If you need more details about any specific event, feel free to ask!
#
# > Finished chain.
# {'input': 'Find me the events happening in the next 12 months.',
#  'output': "Here are the events happening in the next 12 months:\n\n| Event Name                                               | Start Date  | End Date    | Venue                                                        | Country               |\n|---------------------------------------------------------|-------------|-------------|--------------------------------------------------------------|-----------------------|\n| SG Pet Festival 2024                                    | 2024-08-02  | 2024-08-04  | Marina Bay Sands Singapore Convention Centre, Level 1, Hall A, B & C | None                  |\n| MBA and Master's Fair in Singapore                      | 2024-08-17  | 2024-08-17  | Carlton Hotel Singapore                                      | None                  |\n| ISPE Singapore Conference & Exhibition 2024             | 2024-08-28  | 2024-08-30  | Suntec Singapore                                            | None                  |\n| The Business Show Asia                                   | 2024-08-28  | 2024-08-29  | Sands Expo & Convention Centre                               | None                  |\n| Yummy Food Expo 2024                                    | 2024-08-29  | 2024-09-01  | Singapore Expo                                              | None                  |\n| ISS World Asia                                          | 2024-09-03  | 2024-09-05  | None                                                         | None                  |\n| Seafood Expo Asia                                       | 2024-09-04  | 2024-09-06  | Sands Expo and Convention Centre                             | None                  |\n| BEX Asia                                                | 2024-09-04  | 2024-09-06  | Marina Bay Sands                                            | None                  |\n| MEDICAL FAIR ASIA                                       | 2024-09-11  | 2024-09-13  | Marina Bay Sands                                            | None                  |\n| CeMAT Southeast Asia                                    | 2024-09-12  | 2024-09-14  | Singapore EXPO                                             | Singapore             |\n| DigiMarCon Asia Pacific 2024-Digital Marketing Conference & Exhibition | 2024-09-19  | 2024-09-20  | Marina Bay Sands Expo and Convention Centre                 | Australia             |\n| International Conference and Exhibition on Pharmaceutics and Drug Delivery Systems | 2024-09-23  | 2024-09-24  | Singapore                                                   | None                  |\n| Submarine Networks World 2024                            | 2024-09-25  | 2024-09-26  | Suntec Convention Centre                                     | None                  |\n| Cyber Security World Asia                                | 2024-10-09  | 2024-10-10  | Marina Bay Sands                                            | None                  |\n| eCommerce Expo Asia                                     | 2024-10-09  | 2024-10-10  | Marina Bay Sands Expo & Convention Centre                   | None                  |\n| Big Data & AI World Asia                                 | 2024-10-09  | 2024-10-10  | Marina Bay Sands Expo & Convention Centre                   | None                  |\n| Cloud Expo Asia Singapore 2024                          | 2024-10-09  | 2024-10-10  | Marina Bay Sands                                            | None                  |\n| Industrial Transformation ASIA-PACIFIC 2024            | 2024-10-14  | 2024-10-16  | Singapore EXPO                                             | Singapore             |\n| Accounting & Business Show Asia 2024                    | 2024-10-16  | 2024-10-17  | Sands Expo & Convention Centre, Singapore                   | None                  |\n| Worldchefs Congress & Expo 2024                         | 2024-10-20  | 2024-10-25  | Singapore                                                   | None                  |\n| ITB Asia             ...

# %%
agent.invoke({"input": "Find me the companies that are attending events in the next 3 months."})
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_query_checker` with `{'query': "SELECT DISTINCT c.company_name, c.company_overview, e.event_name, e.event_start_date \nFROM company c \nJOIN event e ON c.event_url = e.event_url \nWHERE e.event_start_date BETWEEN CURRENT_DATE AND CURRENT_DATE + INTERVAL '3 months' \nORDER BY e.event_start_date;"}`
#
#
# ```sql
# SELECT DISTINCT c.company_name, c.company_overview, e.event_name, e.event_start_date
# FROM company c
# JOIN event e ON c.event_url = e.event_url
# WHERE e.event_start_date BETWEEN CURRENT_DATE AND CURRENT_DATE + INTERVAL '3 months'
# ORDER BY e.event_start_date;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT DISTINCT c.company_name, c.company_overview, e.event_name, e.event_start_date \nFROM company c \nJOIN event e ON c.event_url = e.event_url \nWHERE e.event_start_date BETWEEN CURRENT_DATE AND CURRENT_DATE + INTERVAL '3 months' \nORDER BY e.event_start_date;"}`
#
#
# Error: (psycopg2.errors.UndefinedFunction) operator does not exist: text >= date
# LINE 4: WHERE e.event_start_date BETWEEN CURRENT_DATE AND CURRENT_DA...
#                                  ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.
#
# [SQL: SELECT DISTINCT c.company_name, c.company_overview, e.event_name, e.event_start_date
# FROM company c
# JOIN event e ON c.event_url = e.event_url
# WHERE e.event_start_date BETWEEN CURRENT_DATE AND CURRENT_DATE + INTERVAL '3 months'
# ORDER BY e.event_start_date;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Invoking: `sql_db_query_checker` with `{'query': "SELECT DISTINCT c.company_name, c.company_overview, e.event_name, e.event_start_date \nFROM company c \nJOIN event e ON c.event_url = e.event_url \nWHERE e.event_start_date::date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '3 months')::date \nORDER BY e.event_start_date;"}`
#
#
# ```sql
# SELECT DISTINCT c.company_name, c.company_overview, e.event_name, e.event_start_date
# FROM company c
# JOIN event e ON c.event_url = e.event_url
# WHERE e.event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '3 months')
# ORDER BY e.event_start_date;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT DISTINCT c.company_name, c.company_overview, e.event_name, e.event_start_date \nFROM company c \nJOIN event e ON c.event_url = e.event_url \nWHERE e.event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '3 months')::date \nORDER BY e.event_start_date;"}`
#
#
# Error: (psycopg2.errors.UndefinedFunction) operator does not exist: text >= date
# LINE 4: WHERE e.event_start_date BETWEEN CURRENT_DATE AND (CURRENT_D...
#                                  ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.
#
# [SQL: SELECT DISTINCT c.company_name, c.company_overview, e.event_name, e.event_start_date
# FROM company c
# JOIN event e ON c.event_url = e.event_url
# WHERE e.event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '3 months')::date
# ORDER BY e.event_start_date;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Invoking: `sql_db_query_checker` with `{'query': "SELECT DISTINCT c.company_name, c.company_overview, e.event_name, e.event_start_date \nFROM company c \nJOIN event e ON c.event_url = e.event_url \nWHERE e.event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '3 months') \nORDER BY e.event_start_date;"}`
#
#
# ```sql
# SELECT DISTINCT c.company_name, c.company_overview, e.event_name, e.event_start_date
# FROM company c
# JOIN event e ON c.event_url = e.event_url
# WHERE e.event_start_date BETWEEN CURRENT_DATE AND (CURRENT_DATE + INTERVAL '3 months')
# ORDER BY e.event_start_date;
# ```
# Invoking: `sql_db_query` with `{'query': "SELECT DISTINCT c.company_name, c.company_overview, e.event_name, e.event_start_date \nFROM company c \nJOIN event e ON c.event_url = e.event_url \nWHERE e.event_start_date BETWEEN CURRENT_DATE::text AND (CURRENT_DATE + INTERVAL '3 months')::text \nORDER BY e.event_start_date;"}`
#
#
# [('Alcatel Submarine Networks', 'ASN Information\nAlcatel Submarine Networks, part of Nokia, leads the industry in terms of transmission capacity and installed base with more than 750,000 km of optical submarine systems deployed worldwide (enough to circumnavigate the globe 19 times!) From traditional telecom applications to...', 'Submarine Networks World 2024', '2024-09-25'), ('Amazon Web Services (Aws)', 'Launched in 2006, Amazon Web Services (AWS) began exposing key infrastructure services to businesses in the form of web services--now widely known as cloud computing. The ultimate benefit of cloud computing, and AWS, is the ability to leverage a new business model and turn capital infrastructure...', 'Submarine Networks World 2024', '2024-09-25'), ('Anritsu', 'Anritsu (est.1895 in Japan) manufactures product inspection and detection equipment for food and pharma industries. Part of the Product Quality Assurance division of Anritsu Corp., we advance quality control programs with high-performing and reliable solutions. Our X-Ray Systems, Checkweighers,...', 'Submarine Networks World 2024', '2024-09-25'), ('Aptelecom', "APTelecom is an award-winning digital infrastructure consulting firm founded in 2009 focused on Vision 2025. APTelecom's reach and expertise spans a wide range of emerging global markets. Among the company's core offerings are fiber sales, due diligence, data center and strategic consulting...", 'Submarine Networks World 2024', '2024-09-25'), ('Britannica Home', 'Britannica Home Information\nEstablished in 1768, Encyclopdia Britannica is headquartered in Chicago, Illinois. They are a general knowledge online encyclopedia.\nView Top Employees from Britannica Home', 'Submarine Networks World 2024', '2024-09-25'), ('Cardinal Spellman High School-Bronx', 'Cardinal Spellman HS Information\nCardinal Spellman HS is a Education Administration Programs company based at 1 Cardinal Spellman Pl, Bronx, New York 10466, US founded in Jan. 1, 1959, midnight.\nView Top Employees from Cardinal Spellman HS', 'Submarine Networks World 2024', '2024-09-25'), ('Ciena', "Ciena (NYSE:CIEN) is a global leader in optical and routing systems, services, and automation software. We build the world's most adaptive networks to address ever-increasing digital demands for richer, more connected experiences for all users. For three-plus decades, we've brought our innate...", 'Submarine Networks World 2024', '2024-09-25'), ('Ciena Healthcare', 'Ciena Healthcare Information\nCiena Healthcare is a leading innovator and provider of skilled nursing and rehabilitation care services. Our Centers offer a full spectrum of post-hospital stay services that you may need following a hospital discharge, from a short-term rehabilitation stay to long...', 'Submarine Networks World 2024', '2024-09-25'), ('Cisco', 'Cisco (NASDAQ: CSCO) enables people to make powerful connections--whether in business, education, philanthropy, or creativity. Cisco hardware, software, and service offerings are used to create the Internet solutions that make networks possible--providing easy access to information anywhere, at...', 'Submarine Networks World 2024', '2024-09-25'), ('Cisco Networking Academy', 'Cisco Networking Academy Information\nCisco Networking Academy is an IT skills-to-jobs program offering digital skills training through strong public-private partnerships, high-quality curriculum, and inclusive workforce development programs. We are one of the longest-running, purpose-driven...', 'Submarine Networks World 2024', '2024-09-25'), ('Digital Realty', 'Digital Realty brings companies and data together by delivering the full spectrum of data center, colocation and interconnection solutions. PlatformDIGITAL®, the company\'s global data center platform, provides customers with a secure data "meeting place". Digital Realty enables its customers...', 'Submarine Networks World 2024', '2024-09-25'), ('Engadget', "Engadget Information\nTechnology isn't just about gadgets. It's ...
#
# | Company Name                          | Company Overview                                                                                                                                                                                                 | Event Name                          | Event Start Date |
# |---------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------|------------------|
# | Alcatel Submarine Networks            | ASN Information: Alcatel Submarine Networks, part of Nokia, leads the industry in terms of transmission capacity and installed base with more than 750,000 km of optical submarine systems deployed worldwide. | Submarine Networks World 2024       | 2024-09-25       |
# | Amazon Web Services (Aws)            | Launched in 2006, AWS began exposing key infrastructure services to businesses in the form of web services--now widely known as cloud computing.                                                                  | Submarine Networks World 2024       | 2024-09-25       |
# | Anritsu                               | Anritsu manufactures product inspection and detection equipment for food and pharma industries.                                                                                                               | Submarine Networks World 2024       | 2024-09-25       |
# | Aptelecom                             | APTelecom is an award-winning digital infrastructure consulting firm focused on Vision 2025.                                                                                                                  | Submarine Networks World 2024       | 2024-09-25       |
# | Britannica Home                       | Established in 1768, Encyclopdia Britannica is headquartered in Chicago, Illinois. They are a general knowledge online encyclopedia.                                                                            | Submarine Networks World 2024       | 2024-09-25       |
# | Cardinal Spellman High School-Bronx  | Cardinal Spellman HS is an Education Administration Programs company based in Bronx, New York.                                                                                                               | Submarine Networks World 2024       | 2024-09-25       |
# | Ciena                                 | Ciena is a global leader in optical and routing systems, services, and automation software.                                                                                                                    | Submarine Networks World 2024       | 2024-09-25       |
# | Cisco                                 | Cisco enables people to make powerful connections--whether in business, education, philanthropy, or creativity.                                                                                                 | Submarine Networks World 2024       | 2024-09-25       |
# | Digital Realty                        | Digital Realty brings companies and data together by delivering the full spectrum of data center, colocation and interconnection solutions.                                                                       | Submarine Networks World 2024       | 2024-09-25       |
# | Google                                | Google builds products that help create opportunities for everyone, whether down the street or across the globe.                                                                                               | Submarine Networks World 2024       | 2024-09-25       |
# | Pfizer                                | To apply science and our global resources to improve health and well-being at every stage of life.                                                                                                            | 2nd Edition of Global Conference on Gynecology & Women's Health | 2024-10-17       |
# | Unilever Food Solutions-India        | Unilever Food Solutions is dedicated to providing high-quality food solutions.                                                                                                                                 | Worldchefs Congress & Expo 2024     | 2024-10-20       |
#
# This table includes a selection of companies along with their overviews, the events they are attending, and the respective start dates. If you need more information or additional companies, feel free to ask!
#
# > Finished chain.
# {'input': 'Find me the companies that are attending events in the next 3 months.',
#  'output': "Here are some companies that are attending events in the next three months:\n\n| Company Name                          | Company Overview                                                                                                                                                                                                 | Event Name                          | Event Start Date |\n|---------------------------------------|------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|-------------------------------------|------------------|\n| Alcatel Submarine Networks            | ASN Information: Alcatel Submarine Networks, part of Nokia, leads the industry in terms of transmission capacity and installed base with more than 750,000 km of optical submarine systems deployed worldwide. | Submarine Networks World 2024       | 2024-09-25       |\n| Amazon Web Services (Aws)            | Launched in 2006, AWS began exposing key infrastructure services to businesses in the form of web services--now widely known as cloud computing.                                                                  | Submarine Networks World 2024       | 2024-09-25       |\n| Anritsu                               | Anritsu manufactures product inspection and detection equipment for food and pharma industries.                                                                                                               | Submarine Networks World 2024       | 2024-09-25       |\n| Aptelecom                             | APTelecom is an award-winning digital infrastructure consulting firm focused on Vision 2025.                                                                                                                  | Submarine Networks World 2024       | 2024-09-25       |\n| Britannica Home                       | Established in 1768, Encyclopdia Britannica is headquartered in Chicago, Illinois. They are a general knowledge online encyclopedia.                                                                            | Submarine Networks World 2024       | 2024-09-25       |\n| Cardinal Spellman High School-Bronx  | Cardinal Spellman HS is an Education Administration Programs company based in Bronx, New York.                                                                                                               | Submarine Networks World 2024       | 2024-09-25       |\n| Ciena                                 | Ciena is a global leader in optical and routing systems, services, and automation software.                                                                                                                    | Submarine Networks World 2024       | 2024-09-25       |\n| Cisco                                 | Cisco enables people to make powerful connections--whether in business, education, philanthropy, or creativity.                                                                                                 | Submarine Networks World 2024       | 2024-09-25       |\n| Digital Realty                        | Digital Realty brings companies and data together by delivering the full spectrum of data center, colocation and interconnection solutions.                                                                       | Submarine Networks World 2024       | 2024-09-25       |\n| Google                                | Google builds products that help create opportunities for everyone, whether down the street or across the globe.                                                                                               | Submarine Networks World 2024       | 2024-09-25       |\n| Pfizer                                | To apply science and our global resources to improve health and well-being at every stage of life.                                                        ...

# %%
agent.invoke({"input": "Find events that already over."})
# Out:
# > Entering new SQL Agent Executor chain...
#
# Invoking: `sql_db_query_checker` with `{'query': 'SELECT event_name, event_start_date, event_end_date FROM event WHERE event_end_date < CURRENT_DATE ORDER BY event_end_date DESC;'}`
#
#
# ```sql
# SELECT event_name, event_start_date, event_end_date FROM event WHERE event_end_date < CURRENT_DATE ORDER BY event_end_date DESC;
# ```
# Invoking: `sql_db_query` with `{'query': 'SELECT event_name, event_start_date, event_end_date FROM event WHERE event_end_date < CURRENT_DATE ORDER BY event_end_date DESC;'}`
#
#
# Error: (psycopg2.errors.UndefinedFunction) operator does not exist: text < date
# LINE 1: ...e, event_end_date FROM event WHERE event_end_date < CURRENT_...
#                                                              ^
# HINT:  No operator matches the given name and argument type(s). You might need to add explicit type casts.
#
# [SQL: SELECT event_name, event_start_date, event_end_date FROM event WHERE event_end_date < CURRENT_DATE ORDER BY event_end_date DESC;]
# (Background on this error at: https://sqlalche.me/e/20/f405)
# Invoking: `sql_db_query_checker` with `{'query': 'SELECT event_name, event_start_date, event_end_date FROM event WHERE event_end_date::date < CURRENT_DATE ORDER BY event_end_date DESC;'}`
#
#
# ```sql
# SELECT event_name, event_start_date, event_end_date FROM event WHERE event_end_date < CURRENT_DATE ORDER BY event_end_date DESC;
# ```
# Invoking: `sql_db_query` with `{'query': 'SELECT event_name, event_start_date, event_end_date FROM event WHERE event_end_date::date < CURRENT_DATE ORDER BY event_end_date DESC;'}`
#
#
# [('AFA Creators Super Fest 2024', '2024-07-27', '2024-07-28'), ('2024 IEEE International Conference on Multimedia and Expo', '2024-07-15', '2024-07-19'), ('2024 IEEE International Conference on Multimedia and Expo', '2024-07-15', '2024-07-19'), ('ZAK Salaam India Expo', '2024-07-11', '2024-07-14'), ('World Food Fair', '2024-07-04', '2024-07-07'), ('World University Expo @ SUNTEC', '2024-07-06', '2024-07-06')]Here are the events that have already concluded:
#
# | Event Name                                         | Start Date  | End Date    |
# |----------------------------------------------------|-------------|-------------|
# | AFA Creators Super Fest 2024                       | 2024-07-27  | 2024-07-28  |
# | 2024 IEEE International Conference on Multimedia and Expo | 2024-07-15  | 2024-07-19  |
# | ZAK Salaam India Expo                               | 2024-07-11  | 2024-07-14  |
# | World Food Fair                                     | 2024-07-04  | 2024-07-07  |
# | World University Expo @ SUNTEC                     | 2024-07-06  | 2024-07-06  |
#
# Please note that the dates listed are in the future, and thus these events have not yet occurred. If you need information on past events, please let me know!
#
# > Finished chain.
# {'input': 'Find events that already over.',
#  'output': 'Here are the events that have already concluded:\n\n| Event Name                                         | Start Date  | End Date    |\n|----------------------------------------------------|-------------|-------------|\n| AFA Creators Super Fest 2024                       | 2024-07-27  | 2024-07-28  |\n| 2024 IEEE International Conference on Multimedia and Expo | 2024-07-15  | 2024-07-19  |\n| ZAK Salaam India Expo                               | 2024-07-11  | 2024-07-14  |\n| World Food Fair                                     | 2024-07-04  | 2024-07-07  |\n| World University Expo @ SUNTEC                     | 2024-07-06  | 2024-07-06  |\n\nPlease note that the dates listed are in the future, and thus these events have not yet occurred. If you need information on past events, please let me know!'}
